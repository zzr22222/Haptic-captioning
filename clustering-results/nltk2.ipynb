# %%
import pandas as pd
from nltk.corpus import sentiwordnet as swn

# 读取CSV文件
df = pd.read_csv('filtered_fine_tune_res.csv')

# 初始化结果字典
result_data = {'Participants': [], 'Signal': [], 'filtered_words': [], 'Final Sentiment': []}

# 提取filtered_tags列，并将其分割为单个词列表
for index, row in df.iterrows():
    words_list = str(row['filtered_tags']).split(',')

    # 去除空字符串
    words_list = [word for word in words_list if word.strip()]

    # 对于每一个词或词组
    for item in words_list:
        words = item.split()
        contains_not = "not" in words  # 检查是否包含"not"

        total_pos = total_neg = 0
        count = 0
        for word in words:
            if word == 'not':
                continue
            senti_synsets = list(swn.senti_synsets(word))
            
            for synset in senti_synsets:
                total_pos += synset.pos_score()
                total_neg += synset.neg_score()
                count += 1

        avg_pos = avg_neg = 0
        if count != 0:
            avg_pos = total_pos / count
            avg_neg = total_neg / count
        elif contains_not:
            not_synsets = list(swn.senti_synsets('not', 'r'))
            avg_pos = not_synsets[0].pos_score()
            avg_neg = not_synsets[0].neg_score()

        # 如果包含"not"，根据情况反转情感分数或使用not的情感得分
        if contains_not:
            if avg_pos == avg_neg:  # 中性
                not_synsets = list(swn.senti_synsets('not', 'r'))
                avg_pos = not_synsets[0].pos_score()
                avg_neg = not_synsets[0].neg_score()
            else:
                avg_pos, avg_neg = avg_neg, avg_pos

        # 判断最终的情感属性
        final_sentiment = "Neutral"
        if avg_pos > 0.25 and avg_pos > avg_neg:
            final_sentiment = "Positive"
        elif avg_neg > 0.25 and avg_neg > avg_pos:
            final_sentiment = "Negative"

        # 将结果添加到结果字典中
        result_data['Participants'].append(row['Participants'])
        result_data['Signal'].append(row['Signal'])
        result_data['filtered_words'].append(item)
        result_data['Final Sentiment'].append(final_sentiment)

# 将结果字典转换为DataFrame，并保存为CSV文件
result_df = pd.DataFrame(result_data)
result_df.to_csv("sentiment_results2.csv", index=False)

# %%
## 分积极和消极的词
import pandas as pd

# 读取 NRC-Emotion-Lexicon.csv
nrc_emotion = pd.read_csv('/Users/zhaozirui/Desktop/ASU-visiting student/11.2/NRC-Emotion-Lexicon.csv')

# 读取 filtered_fine_tune_res.csv
filtered_res = pd.read_csv('filtered_fine_tune_res.csv')

# 创建新的DataFrame来保存结果
result_df = []

# 根据词语和情感表判断最终情感
def get_sentiment(tag, emotion_df):
    emotion_row = emotion_df[emotion_df['Words'] == tag]
    
    if emotion_row.empty:
        return 'Neutral'
    
    # 统计Positive, Anticipation, Joy, Surprise, Trust的1的个数
    positive_count = emotion_row[['Positive', 'Anticipation', 'Joy', 'Surprise', 'Trust']].sum(axis=1).values[0]
    #positive_count = emotion_row[['Positive']].sum(axis=1).values[0]


    # 统计Negative, Anger, Disgust, Fear, Sadness的1的个数
    negative_count = emotion_row[['Negative', 'Anger', 'Disgust', 'Fear', 'Sadness','Surprise']].sum(axis=1).values[0]
    #negative_count = emotion_row[['Negative']].sum(axis=1).values[0]

    
    print(tag,positive_count,negative_count)
    
    # 判断情感
    if positive_count > negative_count:
        return 'Positive'
    elif positive_count < negative_count:
        return 'Negative'
    elif positive_count == negative_count !=0:
        return 'Positive,Negative'
    else: 
        return 'Neutral'

# 遍历filtered_res中的每一个filtered_tags
for index, row in filtered_res.iterrows():
    tags = str(row['filtered_tags']).split(',')  # 将filtered_tags分成单个单词或词组，以逗号为分隔符
    for tag in tags:
        tag = tag.strip()
        
        # 检查not
        if tag.startswith('not '):
            sentiment = get_sentiment(tag[4:], nrc_emotion)  # 考虑not后面的词
            # 反转情感
            if sentiment == 'Positive':
                sentiment = 'Negative'
            elif sentiment == 'Negative':
                sentiment = 'Positive'
        else:
            sentiment = get_sentiment(tag, nrc_emotion)
        
        result_df.append({
            'Participants': row['Participants'],
            'Signal': row['Signal'],
            'filtered_words': tag,
            'Final Sentiment': sentiment
        })

# 保存结果为sentiment_results3.csv
pd.DataFrame(result_df).to_csv('sentiment_results5.csv', index=False)
# Out:
# beach 1 0
# friend 3 0
# distressing 0 3
# pleasant 5 1
# pleasant 5 1
# excited 5 1
# satisfied 2 0
# static 0 0
# alien 0 3
# massage 2 0
# feeling 5 6
# rhythm 1 0
# regular 0 0
# pulse 0 0
# regular 0 0
# distressed 0 2
# urgent 2 3
# alarm 1 3
# important 2 0
# soothing 3 0
# alarm 1 3
# familiar 2 0
# regular 0 0
# fluffy 0 0
# indirect 0 0
# regular 0 0
# intense 4 5
# alarm 1 3
# unpleasant 0 3
# pleasant 5 1
# constant 2 0
# oppression 0 5
# oppressive 0 5
# empty 0 0
# feeling 5 6
# train 0 0
# horse 1 0
# excited 5 1
# alarming 1 3
# train 0 0
# soothing 3 0
# train 0 0
# passive 0 1
# satisfied 2 0
# game 0 0
# shaving 0 0
# constant 2 0
# pulse 0 0
# steady 2 1
# urgent 2 3
# club 0 0
# shaving 0 0
# sensation 0 0
# constant 2 0
# printer 0 0
# printing 0 0
# rhythm 1 0
# satisfied 2 0
# mundane 0 0
# laundry 0 0
# boredom 0 2
# satisfaction 0 0
# passenger 1 0
# distressed 0 2
# unpleasant 0 3
# boring 0 1
# excited 5 1
# dominant 0 2
# neutral 2 0
# balloon 0 0
# numb 0 1
# distressed 0 2
# satisfied 2 0
# interchangeable 0 0
# waiting 0 0
# vibration 0 0
# quiet 1 1
# quiet 1 1
# water 0 0
# excited 5 1
# boring 0 1
# distressed 0 2
# satisfied 2 0
# dominant 0 2
# rubber 0 0
# uncomfortable 0 1
# distressed 0 2
# excited 5 1
# satisfied 2 0
# familiar 2 0
# agitated 0 2
# unpredictable 1 2
# nervous 1 2
# shock 1 4
# satisfied 2 0
# excited 5 1
# dominant 0 2
# consistent 0 0
# clock 1 0
# constant 2 0
# frantic 2 4
# intense 4 5
# bomb 1 5
# sore 0 3
# pencil 0 0
# wooden 0 0
# wood 0 0
# splint 0 0
# uncomfortable 0 1
# loop 0 0
# globe 0 0
# light 0 0
# finger 0 0
# intense 4 5
# dominating 0 0
# rough 0 0
# annoying 0 2
# paper 0 0
# sticking 0 0
# irritating 0 3
# wet 0 0
# mirror 0 0
# sticky 0 1
# happy 4 0
# depressed 0 4
# benign 2 0
# electric 3 1
# staccato 1 0
# staccato 1 0
# anxious 1 2
# benign 2 0
# difficult 0 1
# discreet 2 0
# attentive 2 0
# periodical 0 0
# annoying 0 2
# staccato 1 0
# resistance 0 2
# jagged 0 0
# annoying 0 2
# resistant 0 2
# resistance 0 2
# constant 2 0
# constant 2 0
# annoying 0 2
# resistant 0 2
# aggressive 0 3
# aggressive 0 3
# motor 0 0
# buzz 2 1
# bee 0 2
# satisfied 2 0
# dangerous 0 2
# cute 1 0
# intrusive 1 5
# aggressive 0 3
# aggressive 0 3
# aggressive 0 3
# obstruction 0 1
# exciting 4 1
# mysterious 2 2
# anxious 1 2
# switch 0 0
# dramatic 0 0
# engine 0 0
# unstable 1 3
# finger 0 0
# engine 0 0
# engine 0 0
# anxious 1 2
# surprised 1 1
# vibration 0 0
# distressed 0 2
# dominant 0 2
# friendly 4 0
# kind 3 0
# anxious 1 2
# chill 0 0
# recommend 2 0
# necessarily 0 0
# relief 1 0
# static 0 0
# static 0 0
# prickly 0 1
# small 0 1
# wall 0 0
# wall 0 0
# scratch 0 0
# sound 0 0
# erase 0 2
# window 0 0
# clean 3 0
# frustrated 0 2
# dirt 0 2
# oil 0 0
# grease 0 0
# tiny 0 0
# speck 0 2
# dirt 0 2
# similar 0 0
# resistance 0 2
# dirt 0 2
# dirty 0 2
# gross 0 2
# dirty 0 2
# crazy 0 4
# tiny 0 0
# tiny 0 0
# dirty 0 2
# thin 0 0
# touching 0 0
# fun 3 0
# wooden 0 0
# friction 0 1
# friction 0 1
# surface 0 0
# table 0 0
# uniform 0 0
# dirty 0 2
# glass 0 0
# stuck 0 0
# rubbing 0 0
# flying 1 1
# stuck 0 0
# friction 0 1
# small 0 1
# dusty 0 0
# crazy 0 4
# table 0 0
# neutral 2 0
# clean 3 0
# glass 0 0
# dog 0 0
# cat 0 0
# vibration 0 0
# glass 0 0
# shaving 0 0
# glass 0 0
# pushing 0 0
# dirty 0 2
# friction 0 1
# pushing 0 0
# blowing 0 0
# machine 1 0
# rumble 0 0
# concerned 0 2
# hurt 0 4
# neutral 2 0
# friction 0 1
# small 0 1
# shooting 0 3
# difficult 0 1
# friction 0 1
# plastic 0 0
# steady 2 1
# constant 2 0
# difficult 0 1
# resistance 0 2
# lines 0 1
# cool 1 0
# cold 0 1
# coolness 1 0
# sporadic 0 0
# stopping 0 0
# waves 0 0
# constant 2 0
# stop 0 0
# direction 0 0
# stubbornness 0 0
# pushing 0 0
# glass 0 0
# music 2 1
# glass 0 0
# touch 0 0
# waves 0 0
# stop 0 0
# barrier 0 2
# massage 2 0
# periodic 0 0
# alert 0 0
# stop 0 0
# physical 0 0
# object 0 0
# surface 0 0
# stop 0 0
# friction 0 1
# tingling 0 0
# constant 2 0
# excitement 4 1
# spinning 0 0
# pulse 0 0
# communication 1 0
# communication 1 0
# communication 1 0
# yellow 0 0
# purple 0 0
# color 0 0
# plastic 0 0
# periodic 0 0
# waves 0 0
# stop 0 0
# stop 0 0
# stop 0 0
# stop 0 0
# emphatic 0 0
# spa 5 1
# calmness 0 0
# relaxation 1 0
# relaxed 0 0
# leisurely 1 0
# sauna 0 0
# annoying 0 2
# stopping 0 0
# stop 0 0
# physical 0 0
# force 0 3
# friction 0 1
# friction 0 1
# finger 0 0
# fingerprint 0 0
# uncomfortable 0 1
# spill 0 0
# sticky 0 1
# nasty 0 5
# worse 0 3
# slide 0 0
# creaking 0 1
# vibration 0 0
# bee 0 2
# beehive 0 0
# good 5 1
# game 0 0
# glass 0 0
# drawing 0 0
# brush 0 0
# dark 0 1
# sinister 0 4
# game 0 0
# lower 0 2
# bass 0 0
# running 0 0
# stumble 0 1
# lagging 1 4
# neurotic 0 3
# prompt 0 0
# impatient 1 1
# sea 1 0
# dormant 0 0
# passive 0 1
# restrictive 0 1
# annoying 0 2
# slide 0 0
# passive 0 1
# quiet 1 1
# annoying 0 2
# buzz 2 1
# buzz 2 1
# grease 0 0
# lagging 1 4
# impatient 1 1
# touching 0 0
# pain 0 3
# background 0 0
# aching 0 2
# stable 2 0
# confident 3 0
# leader 2 0
# stable 2 0
# confident 3 0
# continue 3 0
# sticky 0 1
# jam 1 0
# oppressive 0 5
# stop 0 0
# sticky 0 1
# alive 4 0
# action 1 0
# success 3 0
# working 1 0
# negative 0 2
# error 0 2
# lack 0 1
# continuous 0 0
# cringe 0 4
# sticky 0 1
# good 5 1
# startling 1 1
# box 0 0
# action 1 0
# prolonged 0 0
# art 4 2
# fun 3 0
# creative 1 0
# fun 3 0
# creative 1 0
# fun 3 0
# consistent 0 0
# movement 0 0
# illusion 1 2
# searching 0 0
# hairy 0 2
# tracing 0 0
# pattern 0 0
# landscape 0 0
# texture 0 0
# hair 0 0
# radio 1 0
# cat 0 0
# materials 0 0
# touching 0 0
# face 0 0
# slimy 0 2
# thick 0 0
# resistant 0 2
# depth 2 0
# shiver 1 4
# glass 0 0
# pulse 0 0
# buzz 2 1
# complexity 0 1
# variance 0 0
# lottery 1 0
# champagne 0 0
# party 0 0
# face 0 0
# fun 3 0
# silly 1 1
# entertained 2 0
# dagger 0 2
# constant 2 0
# angular 0 0
# unpleasant 0 3
# bed 0 0
# rhythm 1 0
# meditative 0 0
# club 0 0
# rhythm 1 0
# dispersed 0 0
# surface 0 0
# receiving 4 1
# dangerous 0 2
# alarming 1 3
# importance 2 0
# nervous 1 2
# excitement 4 1
# nervousness 0 1
# kid 0 0
# excited 5 1
# afraid 0 2
# rolling 0 0
# big 0 0
# fat 0 3
# brittle 0 0
# glass 0 0
# fracture 0 1
# fragile 0 3
# consistency 2 0
# determination 2 0
# submarine 0 0
# muffled 0 0
# indifference 0 5
# ticklish 0 0
# frustrated 0 2
# similar 0 0
# specific 0 0
# current 0 0
# anxious 1 2
# charming 1 0
# steady 2 1
# delay 0 5
# slow 0 0
# exciting 4 1
# friction 0 1
# finger 0 0
# concentrate 0 0
# constant 2 0
# forget 0 1
# interested 1 2
# beach 1 0
# sand 0 0
# beat 0 0
# spinning 0 0
# energetic 1 0
# connected 0 0
# social 0 0
# haphazard 0 0
# siren 0 2
# warning 0 1
# danger 0 3
# ominous 1 2
# barrack 0 0
# uncomfortable 0 1
# small 0 1
# big 0 0
# interesting 1 0
# pattern 0 0
# exciting 4 1
# stop 0 0
# irritating 0 3
# pattern 0 0
# irritating 0 3
# irritating 0 3
# climax 5 1
# weird 0 2
# impossible 0 2
# surface 0 0
# broken 0 4
# daydreaming 0 0
# vibration 0 0
# cool 1 0
# excited 5 1
# playful 4 2
# fun 3 0
# pressure 0 1
# unsettled 0 4
# insecure 0 4
# light 0 0
# fluffy 0 0
# dog 0 0
# velvety 1 0
# sweet 5 1
# animal 0 0
# lying 0 3
# light 0 0
# slime 0 1
# game 0 0
# fun 3 0
# playful 4 2
# skating 0 0
# calm 1 0
# patient 2 0
# electric 3 1
# anxious 1 2
# electric 3 1
# touched 0 1
# electric 3 1
# weird 0 2
# deaf 0 1
# familiar 2 0
# fun 3 0
# exciting 4 1
# speaker 0 0
# party 0 0
# concert 0 0
# silent 0 0
# music 2 1
# shady 0 2
# trust 1 0
# hooded 0 1
# open 0 0
# wary 0 1
# subtle 0 0
# vigorous 2 0
# alarming 1 3
# subtle 0 0
# uneasy 0 3
# unpredictable 1 2
# alarming 1 3
# computer 0 0
# soothing 3 0
# tender 3 0
# present 5 1
# calm 1 0
# obvious 2 0
# subtle 0 0
# motor 0 0
# stuck 0 0
# vibration 0 0
# intentional 0 0
# subtle 0 0
# winter 0 0
# light 0 0
# tender 3 0
# urgent 2 3
# aggressive 0 3
# urgent 2 3
# aggressive 0 3
# directly 0 0
# touching 0 0
# machinery 0 0
# touching 0 0
# touching 0 0
# car 0 0
# restriction 0 4
# limited 0 3
# resistance 0 2
# slide 0 0
# push 0 0
# pressure 0 1
# alarm 1 3
# alarm 1 3
# excitable 1 0
# erratic 1 2
# energetic 1 0
# worried 0 2
# anxious 1 2
# panic 0 2
# alert 0 0
# panic 0 2
# subtle 0 0
# beat 0 0
# vigilant 2 1
# alarm 1 3
# steady 2 1
# organized 1 0
# alarm 1 3
# panic 0 2
# good 5 1
# panic 0 2
# slow 0 0
# pleasant 5 1
# abrupt 1 1
# subtle 0 0
# notification 1 0
# rugged 0 1
# uneven 0 1
# uneven 0 1
# pattern 0 0
# music 2 1
# rhythm 1 0
# warning 0 1
# computer 0 0
# unsuccessful 0 2
# sound 0 0
# waves 0 0
# surge 1 1
# vibration 0 0
# static 0 0
# sharpness 0 0
# prickly 0 1
# pleasant 5 1
# arousal 0 0
# ongoing 1 0
# subtle 0 0
# attack 0 3
# pronounced 0 0
# easily 0 0
# sudden 1 1
# importance 2 0
# similar 0 0
# sporadic 0 0
# distinguish 0 0
# scattered 0 0
# disappear 0 1
# muddy 0 2
# engine 0 0
# motor 0 0
# standing 1 0
# waiting 0 0
# muddy 0 2
# subtle 0 0
# feeling 5 6
# ticklish 0 0
# notification 1 0
# tingling 0 0
# finger 0 0
# glass 0 0
# wet 0 0
# liquid 0 0
# icy 0 0
# wet 0 0
# cold 0 1
# wrong 0 1
# glass 0 0
# surface 0 0
# fluffy 0 0
# static 0 0
# glass 0 0
# weird 0 2
# sensation 0 0
# feeling 5 6
# phone 0 0
# pleasant 5 1
# tactile 0 0
# phone 0 0
# weird 0 2
# pillow 1 0
# easy 0 0
# kind 3 0
# painting 0 0
# stuck 0 0
# screen 0 0
# sticky 0 1
# unpleasant 0 3
# uncomfortable 0 1
# sequence 0 0
# worse 0 3
# ringing 0 0
# phone 0 0
# vibration 0 0
# urgent 2 3
# pleasant 5 1
# stuck 0 0
# rubber 0 0
# glass 0 0
# pattern 0 0
# vibration 0 0
# familiar 2 0
# ringing 0 0
# music 2 1
# phone 0 0
# speaker 0 0
# texture 0 0
# glass 0 0
# sticky 0 1
# uncomfortable 0 1
# static 0 0
# wood 0 0
# wood 0 0
# hardy 3 0
# wood 0 0
# drawer 0 0
# annoyance 0 3
# continuous 0 0
# skip 0 1
# quiet 1 1
# child 3 0
# playground 5 1
# screen 0 0
# continuous 0 0
# friction 0 1
# glass 0 0
# sand 0 0
# numb 0 1
# continuous 0 0
# light 0 0
# grand 0 0
# continuous 0 0
# ant 0 0
# small 0 1
# sensation 0 0
# uncomfortable 0 1
# glass 0 0
# intense 4 5
# crash 1 4
# shot 1 5
# uneven 0 1
# equal 0 0
# bad 0 5
# intense 4 5
# angry 0 3
# sloppy 0 2
# uncomfortable 0 1

# %%
## 方法1:只用GloVe
import torch
import numpy as np
import pandas as pd
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
from nltk.corpus import wordnet

def load_glove(path):
    embeddings = {}
    with open(path, 'r', encoding='utf-8') as file:
        for line in file:
            values = line.split()
            word = ''.join(values[:-300])
            vector = np.asarray(values[-300:], dtype='float32')
            embeddings[word] = vector
    return embeddings

glove_embeddings = load_glove('/Users/zhaozirui/Downloads/glove.840B.300d.txt')

def get_phrase_embedding(phrase, embeddings):
    words = phrase.split()
    vectors = []
    missing_words = []
    for word in words:
        emb = embeddings.get(word)
        if emb is not None:
            vectors.append(emb)
        else:
            missing_words.append(word)
    if missing_words:
        print(f"Missing words: {', '.join(missing_words)} in phrase: '{phrase}'")
        return None
    return np.mean(vectors, axis=0)

def get_antonym(word):
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            if lemma.antonyms():
                return lemma.antonyms()[0].name()
    return 'not ' + word

# 读取sentiment_results.csv中Final Sentiment为Positive的词
df = pd.read_csv('sentiment_results2.csv')
positive_df = df[df['Final Sentiment'] == 'Positive'] ###
phrases = positive_df['filtered_words'].tolist()
# 去除重复标签
phrases = list(set(phrases))

# 获取嵌入并删除那些静态嵌入为0的短语
valid_embeddings1 = []
valid_phrases1 = []

missing_phrases = []  # 记录静态嵌入为0的短语

processed_phrases = []
for phrase in phrases:
    # 确保 phrase 是字符串
    phrase=phrase.lower()
    if isinstance(phrase, str):
        if phrase.startswith("not "):
            antonym = get_antonym(phrase.split(" ")[1])  # 获取"not"后面词的反义词
            print(phrase + "-->" + antonym)
            processed_phrases.append(antonym)
        else:
            processed_phrases.append(phrase)
    else:
        print(f"Skipping non-string value: {phrase}")
        
processed_phrases = list(set(processed_phrases))

for phrase in processed_phrases:
    
    embedding = get_phrase_embedding(phrase, glove_embeddings)
    if embedding is not None:
        valid_embeddings1.append(embedding)
        valid_phrases1.append(phrase)
    else:
        missing_phrases.append(phrase)

#cluster = AgglomerativeClustering(n_clusters=None, distance_threshold=0).fit(valid_embeddings)
#linked = linkage(valid_embeddings, method='ward')
cluster = AgglomerativeClustering(n_clusters=None, distance_threshold=0,affinity='cosine',linkage='average').fit(valid_embeddings1)

linked = linkage(valid_embeddings1, method='average')
plt.figure(figsize=(30, 25))
subset_phrases = [phrase if idx % 5 == 0 else '' for idx, phrase in enumerate(valid_phrases1)]
dendrogram(linked, orientation='left', labels=subset_phrases)

plt.show()
# Out:
# not cold-->hotness
# not slippery-->nonslippery
# not stressful-->not stressful
# not hurt-->be_well
# not disruptive-->not disruptive
# not annoyed-->not annoyed
# not sad-->glad
# not uncomfortable-->comfortable
# not distressed-->euphoric
# not dangerous-->safe
# not anxious-->not anxious
# not angry-->unangry
# not unpleasant-->pleasant
# not negative-->affirmative
# not distressing-->not distressing
# Missing words: be_well in phrase: 'be_well'
# Missing words: nonslippery in phrase: 'nonslippery'
# Missing words: unangry in phrase: 'unangry'
# /Users/zhaozirui/spacy_nlp/.venv/lib/python3.11/site-packages/sklearn/cluster/_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
## word2vec
import torch
import numpy as np
import pandas as pd
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
from nltk.corpus import wordnet
from gensim.models import KeyedVectors

# 用于加载预训练的Word2Vec模型
def load_word2vec(path):
    return KeyedVectors.load_word2vec_format(path, binary=True)

# 用预训练的Word2Vec模型替换您的GloVe路径
word2vec_embeddings = load_word2vec('/Users/zhaozirui/Downloads/GoogleNews-vectors-negative300.bin')


# 修改get_phrase_embedding函数以使用Word2Vec嵌入
def get_phrase_embedding(phrase, embeddings):
    words = phrase.split()
    vectors = []
    missing_words = []
    for word in words:
        try:
            emb = embeddings[word]
            vectors.append(emb)
        except KeyError:
            missing_words.append(word)
    if missing_words:
        print(f"Missing words: {', '.join(missing_words)} in phrase: '{phrase}'")
        return None
    return np.mean(vectors, axis=0)

def get_antonym(word):
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            if lemma.antonyms():
                return lemma.antonyms()[0].name()
    return 'not ' + word

# 读取sentiment_results.csv中Final Sentiment为Positive的词
df = pd.read_csv('sentiment_results2.csv')
positive_df = df[df['Final Sentiment'] == 'Positive'] ###
phrases = positive_df['filtered_words'].tolist()
# 去除重复标签
phrases = list(set(phrases))

# 获取嵌入并删除那些静态嵌入为0的短语
valid_embeddings2 = []
valid_phrases2 = []

missing_phrases = []  # 记录静态嵌入为0的短语

processed_phrases = []
for phrase in phrases:
    # 确保 phrase 是字符串
    phrase=phrase.lower()
    if isinstance(phrase, str):
        if phrase.startswith("not "):
            antonym = get_antonym(phrase.split(" ")[1])  # 获取"not"后面词的反义词
            print(phrase + "-->" + antonym)
            processed_phrases.append(antonym)
        else:
            processed_phrases.append(phrase)
    else:
        print(f"Skipping non-string value: {phrase}")
        
processed_phrases = list(set(processed_phrases))

for phrase in processed_phrases:
    # 在处理短语嵌入时，使用fasttext_embeddings替代glove_embeddings
    embedding = get_phrase_embedding(phrase, word2vec_embeddings)
    if embedding is not None:
        valid_embeddings2.append(embedding)
        valid_phrases2.append(phrase)
    else:
        missing_phrases.append(phrase)
        

cluster = AgglomerativeClustering(n_clusters=None, distance_threshold=0).fit(valid_embeddings2)

linked = linkage(valid_embeddings2, method='ward')
plt.figure(figsize=(30, 25))
subset_phrases = [phrase if idx % 5 == 0 else '' for idx, phrase in enumerate(valid_phrases2)]
dendrogram(linked, orientation='left', labels=subset_phrases)

plt.show()
# Out:
# not angry-->unangry
# not dangerous-->safe
# not sad-->glad
# not anxious-->not anxious
# not disruptive-->not disruptive
# not stressful-->not stressful
# not distressed-->euphoric
# not cold-->hotness
# not uncomfortable-->comfortable
# not hurt-->be_well
# not distressing-->not distressing
# not annoyed-->not annoyed
# not negative-->affirmative
# not slippery-->nonslippery
# not unpleasant-->pleasant
# Missing words: nonslippery in phrase: 'nonslippery'
# Missing words: be_well in phrase: 'be_well'
# Missing words: unangry in phrase: 'unangry'

# %%
## FastText
import torch
import numpy as np
import pandas as pd
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
from nltk.corpus import wordnet
import fasttext

# 使用预训练的FastText模型替换您的GloVe路径
fasttext_model = fasttext.load_model('/Users/zhaozirui/Downloads/wiki.en/wiki.en.bin')

def get_antonym(word):
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            if lemma.antonyms():
                return lemma.antonyms()[0].name()
    return 'un' + word

# 读取sentiment_results.csv中Final Sentiment为Positive的词
df = pd.read_csv('sentiment_results2.csv')
positive_df = df[df['Final Sentiment'] == 'Positive'] ###
phrases = positive_df['filtered_words'].tolist()
# 去除重复标签
phrases = list(set(phrases))

# 获取嵌入并删除那些静态嵌入为0的短语
valid_embeddings3 = []
valid_phrases3 = []

missing_phrases = []  # 记录静态嵌入为0的短语

processed_phrases = []
for phrase in phrases:
    # 确保 phrase 是字符串
    phrase=phrase.lower()
    if isinstance(phrase, str):
        if phrase.startswith("not "):
            antonym = get_antonym(phrase.split(" ")[1])  # 获取"not"后面词的反义词
            print(phrase + "-->" + antonym)
            processed_phrases.append(antonym)
        else:
            processed_phrases.append(phrase)
    else:
        print(f"Skipping non-string value: {phrase}")
        
processed_phrases = list(set(processed_phrases))

for phrase in processed_phrases:
    # 在处理短语嵌入时，使用fasttext_model
    embedding = fasttext_model.get_word_vector(phrase)
    if embedding is not None:
        valid_embeddings3.append(embedding)
        valid_phrases3.append(phrase)
    else:
        missing_phrases.append(phrase)
        

cluster = AgglomerativeClustering(n_clusters=None, distance_threshold=5).fit(valid_embeddings3)

linked = linkage(valid_embeddings3, method='ward')
plt.figure(figsize=(30, 25))
subset_phrases = [phrase if idx % 5 == 0 else '' for idx, phrase in enumerate(valid_phrases3)]
dendrogram(linked, orientation='left', labels=subset_phrases)

plt.show()
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# not distressing-->undistressing
# not hurt-->be_well
# not slippery-->nonslippery
# not sad-->glad
# not annoyed-->unannoyed
# not stressful-->unstressful
# not negative-->affirmative
# not disruptive-->undisruptive
# not distressed-->euphoric
# not cold-->hotness
# not uncomfortable-->comfortable
# not dangerous-->safe
# not unpleasant-->pleasant
# not angry-->unangry
# not anxious-->unanxious

# %%
import fasttext

# 使用预训练的FastText模型替换您的GloVe路径
fasttext_embeddings = fasttext.load_model('/Users/zhaozirui/Downloads/cc.en.300.bin')
# 获取单词的词向量
word = "example"
word_vector = fasttext_embeddings.get_word_vector(word)

print(f"Vector for word '{word}':\n{word_vector}")
# Out:
# Vector for word 'example':
# [-3.01899910e-02  1.67307898e-03 -3.39188091e-02  1.29165754e-04
#  -3.39024775e-02 -3.52627262e-02  5.44663481e-02 -2.15502288e-02
#   1.57393347e-02 -5.50850853e-03 -9.77861509e-03  6.96822815e-03
#   1.34404376e-02  4.04827148e-02 -5.77299595e-02  2.67399456e-02
#   4.28873971e-02  1.72743984e-02  5.14067225e-02  4.15806361e-02
#  -3.46253510e-03 -4.39561009e-02  4.55061607e-02 -4.61385176e-02
#  -6.82864487e-02 -1.10961404e-02  1.33144371e-02  2.14999523e-02
#   8.21126904e-03 -5.76011557e-03  1.62116960e-02  6.52960828e-03
#   7.23410025e-03 -5.48320338e-02 -1.13268523e-02 -9.41580534e-03
#   3.99618335e-02 -5.51603436e-02 -4.69672195e-05 -5.19470498e-02
#  -3.15293521e-02 -4.06791782e-03 -5.40495440e-02 -1.99173968e-02
#  -8.28304701e-03  4.20339815e-02  2.26341262e-02 -1.23577183e-02
#   1.77250840e-02  2.66364366e-02  2.01242566e-02  1.41719412e-02
#  -4.94768023e-02  3.80847923e-04  1.61610469e-02 -3.24339680e-02
#  -5.72527312e-02 -1.43544767e-02 -1.18667241e-02 -3.18274871e-02
#  -6.09051716e-03 -1.75512806e-02 -1.88941509e-02  6.57918751e-02
#  -1.70362704e-02 -2.38775145e-02  1.10819004e-02 -1.46602560e-02
#  -3.17999572e-02 -1.35541838e-02  9.88431554e-03  1.95524376e-02
#   8.56627128e-04  2.85380837e-02  1.19605416e-03 -7.53230369e-03
#   1.82464644e-02  1.79416984e-02  2.20004246e-02  1.42588979e-02
#  -1.28483716e-02  1.68150403e-02 -5.26246391e-02  6.04731254e-02
#  -3.07555180e-02  2.20271456e-03  4.51202802e-02 -2.25942582e-02
#   8.83257855e-03  5.92258088e-02 -1.49658136e-02  1.42201185e-02
#   5.39260916e-02 -3.98425572e-03 -3.96032594e-02  3.12304823e-03
#   5.90320230e-02  3.23439157e-03  1.42818056e-02 -6.75218878e-03
#  -2.45296024e-02  3.40816006e-03  4.59559560e-02 -1.39415951e-03
#   2.04592310e-02  1.62594113e-02 -8.37885309e-03 -3.22134793e-02
#  -4.18445878e-02 -4.48241830e-04  2.27591917e-02  1.05035067e-01
#  -6.87445840e-03  2.30047964e-02 -1.66694373e-02 -3.09513789e-02
#  -2.53222641e-02 -3.28900246e-03  1.32123509e-03  1.55036040e-02
#  -3.37475166e-02 -3.57205211e-03  8.70069675e-03  1.75750591e-02
#  -1.24017140e-02 -2.35731713e-02 -1.88518390e-02  2.83566769e-02
#  -2.68664323e-02  2.52381712e-02  8.98338947e-03  1.00622699e-03
#   8.73946585e-03  3.65372710e-02  6.62934734e-03  1.60806179e-02
#  -4.48645800e-02 -2.15704460e-03  2.22848281e-02  6.43435214e-03
#   9.87622142e-02  2.15436295e-02  3.47205102e-02  3.54047641e-02
#   4.50347364e-03  2.25602351e-02 -1.13495044e-01  4.40410338e-03
#   4.64368984e-03 -2.14721486e-02 -2.13853847e-02  1.65167563e-02
#   1.68756023e-03  1.81931034e-02 -2.40316298e-02 -5.71350288e-03
#   8.29948485e-02 -2.37549655e-02  4.76049557e-02  3.42812315e-02
#  -5.68080246e-02  2.86809877e-02 -1.83667410e-02 -1.65337063e-02
#   1.88965537e-02 -6.54991530e-03 -1.30027067e-02  8.50359164e-03
#   9.80426185e-03  8.63667112e-03 -5.43191191e-03 -2.04030462e-02
#   7.01134354e-02 -3.55278999e-02 -3.87942046e-03  1.43057987e-04
#  -5.89617901e-03 -9.47824679e-03 -2.04912517e-02 -2.75525413e-02
#   8.56543705e-03  7.33267590e-02 -1.36254393e-02  7.35934302e-02
#  -4.66546882e-03  4.85000014e-02 -4.88026720e-03 -1.31496899e-02
#   3.62132043e-02  2.17573028e-02 -6.75447471e-03 -2.76161060e-02
#   2.80781966e-02  2.22665370e-02  3.42924632e-02  7.54242670e-03
#   1.63343605e-02 -1.64738949e-02 -1.74708981e-02  1.07365660e-01
#  -2.19095685e-02  2.00895593e-02 -1.74494721e-02  8.74210149e-03
#  -9.34810191e-03 -1.11030284e-02  7.86592215e-02 -4.37761750e-03
#   9.68915131e-03  4.93756309e-02 -1.01289777e-02  1.30043291e-02
#   1.04785800e-01  1.78876296e-02  1.05670956e-03  1.08829699e-04
#   2.04011574e-02  4.18889150e-02  5.21203410e-03  6.15003370e-02
#   1.49727371e-02  3.83200264e-03  2.79908534e-02  3.86267006e-02
#  -1.05609549e-02 -4.45089713e-02  4.81903628e-02 -1.21327331e-02
#   2.27318462e-02  3.92154232e-03  6.89725205e-03  3.70222554e-02
#   4.04998809e-02  2.40451097e-02 -1.56110208e-02  4.67110937e-03
#   1.15064029e-02 -2.48153806e-02  2.46032383e-02  2.57952884e-02
#  -2.33337190e-02  6.96498062e-03 -5.69340289e-02 -2.25956216e-02
#   9.39001665e-02  1.69412531e-02 -5.67482132e-03 -2.23616920e-02
#   2.57752202e-02 -4.43150609e-04  5.61242551e-03  3.46367201e-03
#   5.75484149e-02 -4.34293225e-02  2.45434027e-02  1.87426098e-02
#  -2.88753491e-02 -4.59794402e-02  2.81588417e-02 -1.56906452e-02
#   9.10069980e-03  4.89695296e-02 -1.83173083e-02 -1.64116398e-02
#  -7.92704523e-02  3.63688245e-02  3.72983143e-02  9.86254541e-04
#   4.70681004e-02 -4.05500643e-02  9.27161425e-04 -3.91272344e-02
#   2.35815831e-02 -4.02348414e-02 -7.46685788e-02 -2.76269224e-02
#  -7.24740839e-03 -3.28706168e-02 -4.25594440e-03  2.08717268e-02
#  -5.23702800e-03  1.65620688e-02 -6.25159591e-02 -1.05047300e-02
#  -1.36466315e-02  2.26716022e-03 -1.56764835e-02 -8.22888501e-03
#   1.25319045e-02 -4.97945249e-02  6.70799613e-02  2.40621828e-02
#  -4.89284005e-03  1.26976427e-02 -2.12681945e-02 -2.28267461e-02
#  -8.61641113e-03  2.78180651e-02  3.45428102e-03  2.85061654e-02]
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
import torch
import numpy as np
import pandas as pd
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
from transformers import BertTokenizer, BertModel
from nltk.corpus import wordnet

# BERT编码
def get_bert_embedding(text, model, tokenizer):
    inputs = tokenizer("I feel " + text, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)
    relevant_tokens = outputs['last_hidden_state'][0][len(tokenizer.encode("I feel ", add_special_tokens=False)):]
    return relevant_tokens.mean(0).numpy()

def get_antonym(word):
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            if lemma.antonyms():
                return lemma.antonyms()[0].name()
    # 对于找不到反义词的情况
    if word.startswith('un'):
        return word[2:]
    return 'un' + word

tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
bert_model = BertModel.from_pretrained("bert-base-uncased")

# 读取sentiment_results.csv中Final Sentiment为Positive的词
df = pd.read_csv('sentiment_results2.csv')
positive_df = df[df['Final Sentiment'] == 'Neutral'] ###
phrases = positive_df['filtered_words'].tolist()
# 去除重复标签
phrases = list(set(phrases))

processed_phrases = []
for phrase in phrases:
    # 确保 phrase 是字符串
    if isinstance(phrase, str):
        if phrase.startswith("not "):
            antonym = get_antonym(phrase.split(" ")[1])  # 获取"not"后面词的反义词
            print(phrase + "-->" + antonym)
            processed_phrases.append(antonym)
        else:
            processed_phrases.append(phrase)
    else:
        print(f"Skipping non-string value: {phrase}")


# 使用BERT为所有的标签（单词和短语）编码
all_embeddings1 = [get_bert_embedding(phrase, bert_model, tokenizer) for phrase in processed_phrases]

# 聚类
cluster = AgglomerativeClustering(n_clusters=None, distance_threshold=0).fit(all_embeddings1)

linked = linkage(all_embeddings1, method='ward')
plt.figure(figsize=(30, 25))
labels = processed_phrases
subset_labels = [label if idx % 5 == 0 else '' for idx, label in enumerate(labels)]
dendrogram(linked, orientation='left', labels=subset_labels)
plt.show()
# Out:
# not familiar-->unfamiliar
# not open-->close
# not equal-->differ
# not sharp-->dull
# not available-->unavailable
# not bored-->interest
# not excited-->stifle
# not communication-->uncommunication
# not trust-->distrust
# not alarming-->unalarming
# not intentional-->undesigned
# not glass-->unglass
# not touching-->untouching
# not smooth-->roughen
# not concentrating-->decentralize
# not sticky-->unsticky
# not aggressive-->unaggressive
# not strong-->weak
# not directly-->indirectly
# not passive-->active_voice
# not textured-->untextured
# not necessarily-->unnecessarily
# not focusing-->blur
# not dominant-->subordinate
# not relaxing-->tense
# not getting-->leave
# not right-->left
# not light-->dark
# not welcome-->say_farewell
# not continuous-->discontinuous
# not much-->little
# not correct-->falsify
# not still-->agitate
# Skipping non-string value: nan
# not ringing-->unringing
# not pushing-->pull
# not depressed-->elate
# not natural-->unnatural
# not uniform-->multiform
# not electric-->unelectric
# not involved-->obviate
# not consistent-->inconsistent
# not heavy-->light

# %%
##神经网络+Glove+Bert

import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
from sklearn.cluster import AgglomerativeClustering
from transformers import BertTokenizer, BertModel
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

# GloVe加载
def load_glove(path):
    embeddings = {}
    with open(path, 'r', encoding='utf-8') as file:
        for line in file:
            values = line.split()
            word = ''.join(values[:-300])
            vector = np.asarray(values[-300:], dtype='float32')
            embeddings[word] = vector
    return embeddings

glove_embeddings = load_glove('/Users/zhaozirui/Downloads/glove.840B.300d.txt')


def get_embeddings(text, model, tokenizer):
    static_embedding = get_glove_embedding(text)
    # 如果静态嵌入为None，则返回None
    if static_embedding is None:
        return None
    dynamic_embedding = get_bert_embedding(text, model, tokenizer)
    return np.concatenate((static_embedding, dynamic_embedding))

def get_glove_embedding(text):
    words = text.lower().split() ###
    embeddings = []
    
    for word in words:
        if word not in glove_embeddings:
            return None  # 如果单词没有在GloVe中找到，返回None
        embeddings.append(glove_embeddings[word])
        
    avg_embedding = np.mean(embeddings, axis=0)
    return avg_embedding

def get_bert_embedding(text, model, tokenizer):
    inputs = tokenizer("I feel " + text, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)
    relevant_tokens = outputs['last_hidden_state'][0][len(tokenizer.encode("I feel", add_special_tokens=False)):]
    return relevant_tokens.mean(0).numpy()

def get_antonym(word):
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            if lemma.antonyms():
                return lemma.antonyms()[0].name()
    return 'not ' + word

tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")  ####
bert_model = BertModel.from_pretrained("bert-base-uncased")  #####

# 读取sentiment_results.csv中Final Sentiment为Positive的词
df = pd.read_csv('sentiment_results2.csv')
positive_df = df[df['Final Sentiment'] == 'Neutral'] ###
phrases = positive_df['filtered_words'].tolist()
# 去除重复标签
phrases = list(set(phrases))


# 获取嵌入并删除那些静态嵌入为0的短语
valid_embeddings = []
valid_phrases = []

missing_phrases = []  # 记录静态嵌入为0的短语

processed_phrases = []
for phrase in phrases:
    # 确保 phrase 是字符串
    if isinstance(phrase, str):
        if phrase.startswith("not "):
            antonym = get_antonym(phrase.split(" ")[1])  # 获取"not"后面词的反义词
            print(phrase + "-->" + antonym)
            processed_phrases.append(antonym)
        else:
            processed_phrases.append(phrase)
    else:
        print(f"Skipping non-string value: {phrase}")

for phrase in processed_phrases:
    embedding = get_embeddings(phrase, bert_model, tokenizer)
    if embedding is not None:
        valid_embeddings.append(embedding)
        valid_phrases.append(phrase)
    else:
        missing_phrases.append(phrase)
    

all_embeddings = torch.tensor(valid_embeddings, dtype=torch.float32)

# 打印静态嵌入为0的短语
print("以下短语在GloVe中没有找到嵌入：")
for phrase in missing_phrases:
    print(phrase)


# 定义Autoencoder模型
class Autoencoder(nn.Module):
    def __init__(self, input_dim):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 512),
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 128)
        )
        self.decoder = nn.Sequential(
            nn.Linear(128, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
            nn.Linear(512, input_dim)
        )
        
    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# 训练Autoencoder
model = Autoencoder(all_embeddings.size(1))
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

epochs = 100
for epoch in range(epochs):
    optimizer.zero_grad()
    outputs = model(all_embeddings)
    loss = criterion(outputs, all_embeddings)

    loss.backward()
    optimizer.step()
    if epoch % 10 == 0:
        print(f'Epoch {epoch}/{epochs} Loss: {loss.item()}')

# 获取压缩表示形式
with torch.no_grad():
    compressed_embeddings = model.encoder(all_embeddings).numpy()

# 使用AgglomerativeClustering进行聚类
cluster = AgglomerativeClustering(n_clusters=None, distance_threshold=0).fit(compressed_embeddings)
labels = cluster.labels_
print(labels)

linked = linkage(compressed_embeddings, method='ward')
plt.figure(figsize=(30, 25))
labels = valid_phrases
subset_labels = [label if idx % 5 == 0 else '' for idx, label in enumerate(labels)]
dendrogram(linked, orientation='left', labels=subset_labels)
plt.show()
# Out:
# not familiar-->unfamiliar
# not open-->close
# not equal-->differ
# not sharp-->dull
# not available-->unavailable
# not bored-->interest
# not excited-->stifle
# not communication-->not communication
# not trust-->distrust
# not alarming-->unalarming
# not intentional-->undesigned
# not glass-->not glass
# not touching-->not touching
# not smooth-->roughen
# not concentrating-->decentralize
# not sticky-->not sticky
# not aggressive-->unaggressive
# not strong-->weak
# not directly-->indirectly
# not passive-->active_voice
# not textured-->not textured
# not necessarily-->unnecessarily
# not focusing-->blur
# not dominant-->subordinate
# not relaxing-->tense
# not getting-->leave
# not right-->left
# not light-->dark
# not welcome-->say_farewell
# not continuous-->discontinuous
# not much-->little
# not correct-->falsify
# not still-->agitate
# Skipping non-string value: nan
# not ringing-->not ringing
# not pushing-->pull
# not depressed-->elate
# not natural-->unnatural
# not uniform-->multiform
# not electric-->not electric
# not involved-->obviate
# not consistent-->inconsistent
# not heavy-->light
# /var/folders/5d/39y9y0xj6_d23kcfnc1kcs2h0000gn/T/ipykernel_66449/669565770.py:100: UserWarning:
#
# Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:248.)
# 以下短语在GloVe中没有找到嵌入：
# unalarming
# raror
# minutemud
# Haphazardous
# active_voice
# say_farewell
# unsuccessfulness
# Epoch 0/100 Loss: 0.12102678418159485
# Epoch 10/100 Loss: 0.058300189673900604
# Epoch 20/100 Loss: 0.04951860010623932
# Epoch 30/100 Loss: 0.04640365391969681
# Epoch 40/100 Loss: 0.0433969609439373
# Epoch 50/100 Loss: 0.0419938825070858
# Epoch 60/100 Loss: 0.040139682590961456
# Epoch 70/100 Loss: 0.038336656987667084
# Epoch 80/100 Loss: 0.036282479763031006
# Epoch 90/100 Loss: 0.03435565158724785
# [578 488 602 471 426 537 423 389 404 576 316 407 347 543 351 356 412 462
#  599 494 449 566 600 571 403 538 492 577 595 388 509 447 466 321 390 568
#  417 384 594 544 457 430 479 385 554 379 387 469 359 340 450 547 383 484
#  370 556 376 559 380 467 529 485 503 590 574 432 507 346 531 334 393 331
#  395 512 536 418 362 487 397 495 591 588 532 521 317 465 561 592 439 477
#  458 505 365 377 540 489 428 460 303 341 446 589 208 500 533 441 343 371
#  481 378 518 375 391 523 232 358 552 459 483 472 443 328 355 522 409 332
#  326 593 427 601 314 374 579 585 398 444 553 367 419 336 187 517 524 411
#  357 587 386 581 541 490 327 189 597 201 265 349 519 445 520 178 555 530
#  504 545 515 497 455 480 424 551 535 572 546 324 478 563 350 575 293 310
#  285 491 596 440 569 323 470 598 297 565 558 163 557 364 539 222 410 296
#  527 311 448 309 194 396 570 335 268 442 454 319 528 382 315 436 510 549
#  213 300 567 542 338 501 405 486 188 301 305 473 461 211 438 394 348 339
#  224 229 360 322 514 352 415 482 475 270 399 562 452 298 420 307 235 318
#  381 261 437 550 361 402 573 516 368 534 234 508 196 197 304 177 342 198
#  429 295 260 425 209 468 582 220 401 526 282 580 289 233 214 173  98 284
#  179 251 277 269 290 254 161 354 513 372 183 408 257 431 278 329 221 204
#  138 174 413 330 312 498 392 240 287 241 164 474 106 203 306 155 325 258
#  548 192 416 369 274 406 502 496 320 245 294 162 344 283 202 193 288 250
#  456 148 244 435 564 463 200 366 493 147 248 453 464 451 184 586 373 151
#  345 146 238 253 157 226 169 231 158 363 172 239 560 313 243 421 276 128
#  584 337 499 205 292 273 525 191 186 583 182 195 476 230 291 141 262 218
#  114 299 275  96 433 175 215 511 160 263 434 279 181 255 422 281 159 353
#  136 506 121 219 140  95 207 280 249 171 144  93  73 247 237 176 225  97
#  252 228 259 212 168  91 242 167 264 333  90 137 115 116 109 154 134 272
#  100 223  79 400 120 119 266 210 118 267 105 185  86 123 217 111 256 236
#  104 286 199 302 271 130 126 124 101 170 227  47 113 142 156 117  80 139
#  216 166 135 180  70  78 132 103 308 133  52 152 108  89 145  44 129  81
#   77  84 112  99  51 127 107  92  83  57  69 131  41  87  67  49  68 414
#  143  45  88 110  61  53  58  43  64 246 150  34  48 153 125  66 190  55
#   75 149  62  94 206  76  33  37  72 122  38  56  46 165  82  63  30  18
#   60  85 102  28  54  39  31  59  50  29  74  40  24  36  14  25  27  26
#   71  16  13  19  42  35  65  21  32  20  17  22  12  10  23  15   6   8
#    7   9   4  11   5   3   1   2   0]

# %%
#embeddings = [get_phrase_embedding(phrase, glove_embeddings) for phrase in phrases]

print(len(valid_embeddings1))
from sklearn.metrics import silhouette_score
from sklearn.cluster import AgglomerativeClustering
import numpy as np

# 定义可能的簇数量范围
possible_n_clusters = range(4,13)  # 最小为2，最大为样本数量-1

sil_scores = []

# 对每一个可能的簇数量进行评估
for num_clusters in possible_n_clusters:
    clusterer = AgglomerativeClustering(n_clusters=num_clusters)
    preds = clusterer.fit_predict(valid_embeddings1)
    
    # 计算轮廓系数并保存
    score = silhouette_score(valid_embeddings1, preds)
    print(score)
    sil_scores.append(score)

# 找到最大的轮廓系数值对应的簇数量
best_num_clusters = possible_n_clusters[np.argmax(sil_scores)]
print(f"Best number of clusters: {best_num_clusters}")
# Out:
# 67
# 0.05962282
# 0.06889627
# 0.07590187
# 0.067882806
# 0.07492749
# 0.061432816
# 0.06697202
# 0.07182894
# 0.07536444
# Best number of clusters: 6

# %%
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# 列表用于保存每个簇数的评分
scores = []

# 设置一个簇数范围，例如从2到20
cluster_range = range(3,31)

# 对于每个簇数进行一次聚类，并计算紧密度或误差
for n_clusters in cluster_range:
    cluster = AgglomerativeClustering(n_clusters=n_clusters, distance_threshold=None).fit(valid_embeddings2)
    silhouette_avg = silhouette_score(valid_embeddings2, cluster.labels_)
    scores.append(silhouette_avg)


# 使用matplotlib绘制簇数对应的误差
plt.figure(figsize=(10,6))
plt.plot(cluster_range, scores, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %%
import pandas as pd
from sklearn.cluster import AgglomerativeClustering

# 进行聚类
cluster = AgglomerativeClustering(n_clusters=13, distance_threshold=None).fit(valid_embeddings2)

# 创建一个字典，其中键是聚类ID，值是该聚类中的标签列表
clusters = {i: [] for i in range(cluster.n_clusters)}

for label, phrase in zip(cluster.labels_, valid_phrases2):
    clusters[label].append(phrase)


# 创建一个字典来保存聚类结果，之后再转为DataFrame
cluster_dict = {}

# 为每个聚类创建一个键值对
for cluster_id, cluster_phrases in clusters.items():
    cluster_dict[f"Cluster_{cluster_id}"] = cluster_phrases

# 对每个聚类中的词汇进行填充（为了DataFrame的对齐）
max_length = max(len(v) for v in cluster_dict.values())
for key, value in cluster_dict.items():
    value.extend([None] * (max_length - len(value)))

# 转为DataFrame
df_clusters = pd.DataFrame(cluster_dict)

# 保存到CSV文件中
df_clusters.to_csv("w2v4_pos_clusters.csv", index=False)

# %%
## 聚类结果的可视化
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

from sklearn.cluster import AgglomerativeClustering
n_clusters=5

cluster = AgglomerativeClustering(n_clusters=n_clusters, distance_threshold=None).fit(valid_embeddings3) ###
labels = cluster.labels_
print(labels)

all_embeddings_np = np.vstack(valid_embeddings3) ###
print(all_embeddings_np)
tsne_model = TSNE(perplexity=40, n_components=3, init='pca', n_iter=2500, random_state=23)
low_dim_data = tsne_model.fit_transform(all_embeddings_np)
# Out:
# [0 1 0 2 0 0 2 2 2 1 1 0 0 0 0 2 0 0 3 0 2 3 2 0 0 3 4 0 1 2 0 2 0 3 2 2 3
#  2 0 3 3 1 0 0 1 3 0 0 2 1 2 0 3 0 0 2 1 0 0 2 0 1 2 0 2 0 2 2 2 2]
# [[-0.217925   -0.24281175  0.07598633 ...  0.42395082  0.11895593
#    0.10756989]
#  [ 0.15521523  0.05471089 -0.42286834 ... -0.10376061  0.58870274
#   -0.1904048 ]
#  [-0.03064591  0.37116838 -0.35386902 ...  0.31677738  0.50067216
#    0.01961074]
#  ...
#  [ 0.09474791  0.04002193 -0.76369977 ...  0.11788906  0.45621774
#   -0.12810043]
#  [ 0.02175065  0.01876712 -0.33632103 ... -0.17707282  0.29409876
#    0.19704065]
#  [ 0.13653126 -0.11975162 -0.35761356 ...  0.1726725   0.00396965
#    0.1337853 ]]

# %%
import plotly.graph_objects as go

text = []
print(valid_phrases3) ###
for phrase, label in zip(valid_phrases3, labels): ###
    text.append('words: ' + phrase + ' label: ' + str(label))

fig = go.Figure(data=[
    go.Scatter3d(
        x=low_dim_data[:, 0],
        y=low_dim_data[:, 1],
        z=low_dim_data[:, 2],
        mode='markers',
        marker=dict(size=6, color=labels),
        text=text,  # 设置每个点的标签
        hoverinfo='text'  # 当悬停在点上时，只显示text内容
    )
])

fig.update_layout(title="3D t-SNE Visualization with Words", width=800, height=600)
fig.show()
# Out:
# ['importance', 'groovy', 'discreet', 'unnerving', 'happy', 'safe', 'intense', 'unangry', 'alive', 'sparkly', 'cuddly', 'aware', 'friendly', 'nonslippery', 'very', 'flattery', 'comfortable', 'posh', 'sharpness', 'easily', 'unstressful', 'pleasantness', 'milder', 'satisfied', 'grand', 'pleasant', 'be_well', 'glad', 'cute', 'pushy', 'okay', 'unannoyed', 'easy', 'pleasing', 'astounded', 'vigilant', 'coolness', 'undistressing', 'really', 'gentle', 'hotness', 'euphoric', 'complexity', 'kind', 'wispy', 'warmth', 'important', 'affirmative', 'undisruptive', 'playful', 'excitable', 'good', 'soothing', 'recommend', 'positive', 'hedonistic', 'peppy', 'wonder', 'nice', 'attentive', 'success', 'melodic', 'empathetic', 'better', 'unanxious', 'interesting', 'benign', 'gripping', 'pronounced', 'haphazard']

# %%
### 计算每一个信号pos neg neu的单词的比例（单个单词）
import pandas as pd

# 1. 读取CSV文件
df = pd.read_csv('processed_uncase_sentiment_results2.csv')

# 2. 为每个Signal类别计算每个Final Sentiment的比例
result = df.groupby('Signal')['Final Sentiment'].value_counts(normalize=True).unstack().fillna(0)

# 3. 将比例转换为百分比
result_percentage = result * 100

# 4. 打印结果
print(result_percentage)
# Out:
# Final Sentiment    Negative   Positive
# Signal
# 1                 60.000000  40.000000
# 2                 85.714286  14.285714
# 3                 54.545455  45.454545
# 4                 33.333333  66.666667
# 5                 50.000000  50.000000
# 6                 50.000000  50.000000
# 7                100.000000   0.000000
# 8                 66.666667  33.333333
# 9                 66.666667  33.333333
# 10                33.333333  66.666667
# 11                91.666667   8.333333
# 12                78.571429  21.428571
# 13                33.333333  66.666667
# 14                62.500000  37.500000
# 15                70.588235  29.411765
# 16                92.307692   7.692308
# 17                81.250000  18.750000
# 18               100.000000   0.000000
# 19                80.000000  20.000000
# 20                 8.333333  91.666667
# 21                85.714286  14.285714
# 22                90.000000  10.000000
# 23                44.444444  55.555556
# 24                81.818182  18.181818
# 25               100.000000   0.000000
# 26                75.000000  25.000000
# 27                69.230769  30.769231
# 28                66.666667  33.333333
# 29                61.538462  38.461538
# 30                66.666667  33.333333
# 31                44.444444  55.555556
# 32                55.555556  44.444444

# %%
##转换词性、比较级、最高级
import pandas as pd
import nltk
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('punkt')

lemmatizer = WordNetLemmatizer()

def lemmatize_word(word):
     # 获取词性
    pos_tag_tuple = nltk.pos_tag([word])[0]  # 注意[word]这里将单词转化为了一个单元素列表
    pos_tag = pos_tag_tuple[1]
    
    # 如果是比较级或最高级
    if pos_tag in ['JJR','JJS','RBR','RBS','JJ','VBG']:
        return lemmatizer.lemmatize(word, pos='a')
    
    
    # 如果是其他词性，则尝试转换为形容词
    return to_adjective(word)

def to_adjective(word):
    # 尝试查找与该词形态上有关的形容词
    synsets = wn.synsets(word)
    
    for syn in synsets:
        for lemma in syn.lemmas():
            related_forms = lemma.derivationally_related_forms()

            # 为了保存与's'相关的词，如果我们找不到与'a'相关的词
            adj_related_form = None
            
            for related_form in related_forms:
                # 如果找到与'a'相关的词，立即返回
                if related_form.synset().pos() == 'a':
                    return related_form.name().replace('_', ' ')
                elif related_form.synset().pos() == 's':
                    adj_related_form = related_form

            # 如果我们在循环结束后仍然有一个与's'相关的词，返回它
            if adj_related_form:
                return adj_related_form.name().replace('_', ' ')
    
    # 如果既没有找到与's'相关的词，也没有找到与'a'相关的词，返回原词
    return word


# 读取CSV文件
df = pd.read_csv('sentiment_results5.csv')

# 选择Final Sentiment为Positive的词的行
positive_rows = df[df['Final Sentiment'] == 'Positive'].copy()
negative_rows = df[df['Final Sentiment'] == 'Negative'].copy()
# 对这些词进行处理
positive_rows['filtered_words'] = positive_rows['filtered_words'].apply(lemmatize_word)
negative_rows['filtered_words'] = negative_rows['filtered_words'].apply(lemmatize_word)

# 重新排列列并保存到新的CSV文件
columns_order = ['Participants', 'Signal', 'filtered_words', 'Final Sentiment']
positive_rows = positive_rows[columns_order]
negative_rows = negative_rows[columns_order]

positive_rows.to_csv('processed_sentiment_results4.csv',index=False)
negative_rows.to_csv('processed_sentiment_results4.csv',mode='a',index=False)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/zhaozirui/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/zhaozirui/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhaozirui/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import pandas as pd
import nltk
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
word='hotness'
synsets = wn.synsets(word)
for syn in synsets:
    for lemma in syn.lemmas():
        related_forms = lemma.derivationally_related_forms()
        for related_form in related_forms:
            if related_form.synset().pos() == 'a':
                print(related_form.name().replace('_', ' '))
            else :
                print("NONE")
# Out:
# hot
# NONE
# NONE
# NONE
# NONE
# NONE
# NONE

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

nltk.download('averaged_perceptron_tagger')

words = 'coldness'
tagged = pos_tag(word_tokenize(words))
#print(tagged)

lemmatizer = WordNetLemmatizer()

print(lemmatizer.lemmatize(words, pos='a'))
# Out:
# coldness
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/zhaozirui/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
## 方法1:只用GloVe 改进2
import torch
import numpy as np
import pandas as pd
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
from nltk.corpus import wordnet

def load_glove(path):
    embeddings = {}
    with open(path, 'r', encoding='utf-8') as file:
        for line in file:
            values = line.split()
            word = ''.join(values[:-300])
            vector = np.asarray(values[-300:], dtype='float32')
            embeddings[word] = vector
    return embeddings

glove_embeddings = load_glove('/Users/zhaozirui/Downloads/glove.840B.300d.txt')

def get_phrase_embedding(phrase, embeddings):
    words = phrase.split()
    vectors = []
    missing_words = []
    for word in words:
        emb = embeddings.get(word)
        if emb is not None:
            vectors.append(emb)
        else:
            missing_words.append(word)
    if missing_words:
        print(f"Missing words: {', '.join(missing_words)} in phrase: '{phrase}'")
        return None
    return np.mean(vectors, axis=0)

def get_antonym(word):
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            if lemma.antonyms():
                return lemma.antonyms()[0].name()
    return 'not ' + word

# 读取sentiment_results.csv中Final Sentiment为Positive的词
df = pd.read_csv('processed_sentiment_results4.csv')
positive_df = df[df['Final Sentiment'] == 'Negative'] ###
phrases = positive_df['filtered_words'].tolist()
# 去除重复标签
phrases = list(set(phrases))

# 获取嵌入并删除那些静态嵌入为0的短语
valid_embeddings1 = []
valid_phrases1 = []

missing_phrases = []  # 记录静态嵌入为0的短语

processed_phrases = []

# 创建一个映射从原始短语到其antonym或处理后的短语
phrase_to_antonym_mapping = {}

for phrase in phrases:
    # 确保 phrase 是字符串
    phrase=phrase.lower()
    if isinstance(phrase, str):
        if phrase.startswith("not "):
            antonym = get_antonym(phrase.split(" ")[1])  # 获取"not"后面词的反义词
            print(phrase + "-->" + antonym)
            processed_phrases.append(antonym)
            phrase_to_antonym_mapping[phrase] = antonym     
        else:
            processed_phrases.append(phrase)
            phrase_to_antonym_mapping[phrase] = phrase
    else:
        print(f"Skipping non-string value: {phrase}")

# # 读取CSV文件
# df = pd.read_csv('processed_sentiment_results2.csv')

# # 将filtered_words列中的值替换为antonym或处理后的短语
# df['filtered_words'] = df['filtered_words'].str.lower().map(phrase_to_antonym_mapping).fillna(df['filtered_words'])

# # 保存结果到CSV文件
# df.to_csv('processed_with_antonyms.csv', index=False)      
        
processed_phrases = list(set(processed_phrases))

for phrase in processed_phrases:
    
    embedding = get_phrase_embedding(phrase, glove_embeddings)
    if embedding is not None:
        valid_embeddings1.append(embedding)
        valid_phrases1.append(phrase)
    else:
        missing_phrases.append(phrase)

cluster = AgglomerativeClustering(n_clusters=None, distance_threshold=0).fit(valid_embeddings1)

linked = linkage(valid_embeddings1, method='ward')

plt.figure(figsize=(30, 25))
subset_phrases = [phrase if idx % 5 == 0 else '' for idx, phrase in enumerate(valid_phrases1)]
dendrogram(linked, orientation='left', labels=subset_phrases)

plt.show()
# Out:
# not vigorous-->not vigorous
# not electric-->not electric
# not obvious-->unobvious
# not communication-->not communication
# not familiar-->unfamiliar
# not benign-->malignant
# not satisfied-->fall_short_of
# not trust-->distrust
# not excited-->stifle
# not good-->evil
# not velvety-->not velvety
# not pleasant-->unpleasant
# Missing words: frustrative in phrase: 'frustrative'
# Missing words: fall_short_of in phrase: 'fall_short_of'

# %%
## word2vec 2
import torch
import numpy as np
import pandas as pd
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
from nltk.corpus import wordnet
from gensim.models import KeyedVectors

# 用于加载预训练的Word2Vec模型
def load_word2vec(path):
    return KeyedVectors.load_word2vec_format(path, binary=True)

# 用预训练的Word2Vec模型替换您的GloVe路径
word2vec_embeddings = load_word2vec('/Users/zhaozirui/Downloads/GoogleNews-vectors-negative300.bin')


# 修改get_phrase_embedding函数以使用Word2Vec嵌入
def get_phrase_embedding(phrase, embeddings):
    words = phrase.split()
    vectors = []
    missing_words = []
    for word in words:
        try:
            emb = embeddings[word]
            vectors.append(emb)
        except KeyError:
            missing_words.append(word)
    if missing_words:
        print(f"Missing words: {', '.join(missing_words)} in phrase: '{phrase}'")
        return None
    return np.mean(vectors, axis=0)

def get_antonym(word):
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            if lemma.antonyms():
                return lemma.antonyms()[0].name()
    return 'not ' + word

# 读取sentiment_results.csv中Final Sentiment为Positive的词
df = pd.read_csv('processed_sentiment_results4.csv')
positive_df = df[df['Final Sentiment'] == 'Negative'] ###
phrases = positive_df['filtered_words'].tolist()
# 去除重复标签
phrases = list(set(phrases))

# 获取嵌入并删除那些静态嵌入为0的短语
valid_embeddings2 = []
valid_phrases2 = []

missing_phrases = []  # 记录静态嵌入为0的短语

processed_phrases = []
for phrase in phrases:
    # 确保 phrase 是字符串
    phrase=phrase.lower()
    if isinstance(phrase, str):
        if phrase.startswith("not "):
            antonym = get_antonym(phrase.split(" ")[1])  # 获取"not"后面词的反义词
            print(phrase + "-->" + antonym)
            processed_phrases.append(antonym)
        else:
            processed_phrases.append(phrase)
    else:
        print(f"Skipping non-string value: {phrase}")
        
processed_phrases = list(set(processed_phrases))

for phrase in processed_phrases:
    # 在处理短语嵌入时，使用fasttext_embeddings替代glove_embeddings
    embedding = get_phrase_embedding(phrase, word2vec_embeddings)
    if embedding is not None:
        valid_embeddings2.append(embedding)
        valid_phrases2.append(phrase)
    else:
        missing_phrases.append(phrase)
        

cluster = AgglomerativeClustering(n_clusters=None, distance_threshold=0).fit(valid_embeddings2)

linked = linkage(valid_embeddings2, method='ward')

plt.figure(figsize=(30, 25))
subset_phrases = [phrase if idx % 5 == 0 else '' for idx, phrase in enumerate(valid_phrases2)]
dendrogram(linked, orientation='left', labels=subset_phrases)

plt.show()
# Out:
# not vigorous-->not vigorous
# not electric-->not electric
# not obvious-->unobvious
# not communication-->not communication
# not familiar-->unfamiliar
# not benign-->malignant
# not satisfied-->fall_short_of
# not trust-->distrust
# not excited-->stifle
# not good-->evil
# not velvety-->not velvety
# not pleasant-->unpleasant
# Missing words: frustrative in phrase: 'frustrative'
# Missing words: agitative in phrase: 'agitative'
# Missing words: fall_short_of in phrase: 'fall_short_of'

# %%
## FastText 2
import torch
import numpy as np
import pandas as pd
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
from nltk.corpus import wordnet
import fasttext

# 使用预训练的FastText模型替换您的GloVe路径
fasttext_model = fasttext.load_model('/Users/zhaozirui/Downloads/wiki.en/wiki.en.bin')

def get_antonym(word):
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            if lemma.antonyms():
                return lemma.antonyms()[0].name()
    return 'not ' + word  ###

# 读取sentiment_results.csv中Final Sentiment为Positive的词
df = pd.read_csv('processed_sentiment_results4.csv')
positive_df = df[df['Final Sentiment'] == 'Negative'] ###
phrases = positive_df['filtered_words'].tolist()
# 去除重复标签
phrases = list(set(phrases))

# 获取嵌入并删除那些静态嵌入为0的短语
valid_embeddings3 = []
valid_phrases3 = []

missing_phrases = []  # 记录静态嵌入为0的短语

processed_phrases = []

# 创建一个映射从原始短语到其antonym或处理后的短语
phrase_to_antonym_mapping = {}

for phrase in phrases:
    # 确保 phrase 是字符串
    phrase=phrase.lower()
    if isinstance(phrase, str):
        if phrase.startswith("not "):
            antonym = get_antonym(phrase.split(" ")[1])  # 获取"not"后面词的反义词
            print(phrase + "-->" + antonym)
            processed_phrases.append(antonym)
            phrase_to_antonym_mapping[phrase] = antonym 
        else:
            processed_phrases.append(phrase)
            phrase_to_antonym_mapping[phrase] = phrase 
    else:
        print(f"Skipping non-string value: {phrase}")
        
# 读取CSV文件
df = pd.read_csv('processed_sentiment_results4.csv')

# 将filtered_words列中的值替换为antonym或处理后的短语
df['filtered_words'] = df['filtered_words'].str.lower().map(phrase_to_antonym_mapping).fillna(df['filtered_words'])

# 保存结果到CSV文件
df.to_csv('processed_with_pos_antonyms3.csv', index=False)   
        
processed_phrases = list(set(processed_phrases))

for phrase in processed_phrases:
    # 在处理短语嵌入时，使用fasttext_model
    embedding = fasttext_model.get_word_vector(phrase)
    if embedding is not None:
        valid_embeddings3.append(embedding)
        valid_phrases3.append(phrase)
    else:
        missing_phrases.append(phrase)
        

cluster = AgglomerativeClustering(n_clusters=None, distance_threshold=5).fit(valid_embeddings3)

linked = linkage(valid_embeddings3, method='ward')


plt.figure(figsize=(30, 25))
subset_phrases = [phrase if idx % 5 == 0 else '' for idx, phrase in enumerate(valid_phrases3)]
dendrogram(linked, orientation='left', labels=subset_phrases)

plt.show()
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# not vigorous-->not vigorous
# not electric-->not electric
# not obvious-->unobvious
# not communication-->not communication
# not familiar-->unfamiliar
# not benign-->malignant
# not satisfied-->fall_short_of
# not trust-->distrust
# not excited-->stifle
# not good-->evil
# not velvety-->not velvety
# not pleasant-->unpleasant

# %%
## ConceptNet Numberbatch
import torch
import numpy as np
import pandas as pd
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
from nltk.corpus import wordnet
## ConceptNet Numberbatch
from gensim.models import KeyedVectors

# 假设你已经下载了词向量文件到本地路径
numberbatch_path = '/Users/zhaozirui/Desktop/ASU-visiting student/11.9/numberbatch-en-19.08.txt'
# 加载模型（这可能需要一些时间）
numberbatch = KeyedVectors.load_word2vec_format(numberbatch_path, binary=False)

# 修改get_phrase_embedding函数以使用Word2Vec嵌入
def get_phrase_embedding(phrase, embeddings):
    words = phrase.split()
    vectors = []
    missing_words = []
    for word in words:
        try:
            emb = embeddings[word]
            vectors.append(emb)
        except KeyError:
            missing_words.append(word)
    if missing_words:
        print(f"Missing words: {', '.join(missing_words)} in phrase: '{phrase}'")
        return None
    return np.mean(vectors, axis=0)

def get_antonym(word):
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            if lemma.antonyms():
                return lemma.antonyms()[0].name()
    return 'not ' + word

# 读取sentiment_results.csv中Final Sentiment为Positive的词
df = pd.read_csv('processed_sentiment_results4.csv')
positive_df = df[df['Final Sentiment'] == 'Negative'] ###
phrases = positive_df['filtered_words'].tolist()
# 去除重复标签
phrases = list(set(phrases))

# 获取嵌入并删除那些静态嵌入为0的短语
valid_embeddings4 = []
valid_phrases4 = []

missing_phrases = []  # 记录静态嵌入为0的短语

processed_phrases = []
for phrase in phrases:
    # 确保 phrase 是字符串
    phrase=phrase.lower()
    if isinstance(phrase, str):
        if phrase.startswith("not "):
            antonym = get_antonym(phrase.split(" ")[1])  # 获取"not"后面词的反义词
            print(phrase + "-->" + antonym)
            processed_phrases.append(antonym)
        else:
            processed_phrases.append(phrase)
    else:
        print(f"Skipping non-string value: {phrase}")
        
processed_phrases = list(set(processed_phrases))

for phrase in processed_phrases:
    # 在处理短语嵌入时，使用fasttext_embeddings替代glove_embeddings
    embedding = get_phrase_embedding(phrase, numberbatch)
    if embedding is not None:
        valid_embeddings4.append(embedding)
        valid_phrases4.append(phrase)
    else:
        missing_phrases.append(phrase)
        

cluster = AgglomerativeClustering(n_clusters=None, distance_threshold=0).fit(valid_embeddings4)

linked = linkage(valid_embeddings4, method='ward')

plt.figure(figsize=(30, 25))
subset_phrases = [phrase if idx % 5 == 0 else '' for idx, phrase in enumerate(valid_phrases4)]
dendrogram(linked, orientation='left', labels=subset_phrases)

plt.show()
# Out:
# not obvious-->unobvious
# not pleasant-->unpleasant
# not excited-->stifle
# not vigorous-->not vigorous
# not communication-->not communication
# not familiar-->unfamiliar
# not benign-->malignant
# not trust-->distrust
# not electric-->not electric
# not velvety-->not velvety
# not satisfied-->fall_short_of
# not good-->evil

# %%
##处理phrases
import pandas as pd

# 读取CSV文件
df = pd.read_csv("phrase_fine_tune_res.csv")

# 创建一个新的DataFrame来保存处理后的数据
new_rows = []

for index, row in df.iterrows():
    # 对"phrases"列按照逗号进行分割
    phrases = row['phrases'].split(',')
    for phrase in phrases:
        new_rows.append([row['Participants'], row['Signal'], phrase.strip()])

# 将新的数据转换为DataFrame
new_df = pd.DataFrame(new_rows, columns=['Participants', 'Signal', 'phrases'])

# 保存到新的CSV文件
new_df.to_csv("processed_phrase_fine_tune_res.csv", index=False)

# %%
## 只用bert 用于处理词组
import torch
import numpy as np
import pandas as pd
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
from nltk.corpus import wordnet
from transformers import BertTokenizer, BertModel

# 加载预训练的BERT模型和tokenizer
model_name = "bert-base-cased"
model = BertModel.from_pretrained(model_name)
tokenizer = BertTokenizer.from_pretrained(model_name)
model.eval()  # 设置模型为评估模式

def get_bert_embedding(text, model, tokenizer):
    inputs = tokenizer("I feel " + text, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)
    cls_embedding = outputs.last_hidden_state[:, 0, :].squeeze().numpy()
    return cls_embedding

# 读取sentiment_results.csv中Final Sentiment为Positive的词
df = pd.read_csv('processed_phrase_fine_tune_res.csv')``
phrases = df['phrases'].tolist()

# 去除重复标签
phrases = list(set(phrases))

# 获取嵌入并删除那些静态嵌入为0的短语
valid_embeddings4 = []
valid_phrases4 = []

missing_phrases = []  # 记录静态嵌入为0的短语

processed_phrases = []

# 创建一个映射从原始短语到其antonym或处理后的短语
phrase_to_antonym_mapping = {}

for phrase in phrases:
    # 在处理短语嵌入时，使用fasttext_model
    
    embedding = get_bert_embedding(phrase,model,tokenizer)
    if embedding is not None:
        valid_embeddings4.append(embedding)
        valid_phrases4.append(phrase)
    else:
        missing_phrases.append(phrase)
        
cluster = AgglomerativeClustering(n_clusters=None, distance_threshold=0).fit(valid_embeddings4)

linked = linkage(valid_embeddings4, method='ward')

plt.figure(figsize=(30, 25))
subset_phrases = [phrase if idx % 5 == 0 else '' for idx, phrase in enumerate(valid_phrases4)]
dendrogram(linked, orientation='left', labels=subset_phrases)

plt.show()

# %%
## 只用roberta 用于处理词组
import torch
import numpy as np
import pandas as pd
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
from nltk.corpus import wordnet
from transformers import RobertaTokenizer, RobertaModel

# 加载预训练的RoBERTa模型和tokenizer
model_name = "roberta-base"
model = RobertaModel.from_pretrained(model_name)
tokenizer = RobertaTokenizer.from_pretrained(model_name)
model.eval()  # 设置模型为评估模式

def get_roberta_embedding(text, model, tokenizer):
    inputs = tokenizer("I feel " + text, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)
    # 取所有token embeddings的平均作为句子的embedding
    sentence_embedding = outputs.last_hidden_state.mean(dim=1).squeeze().numpy()
    return sentence_embedding

# 读取sentiment_results.csv中Final Sentiment为Positive的词
df = pd.read_csv('processed_phrase_fine_tune_res.csv')
phrases = df['phrases'].tolist()

# 去除重复标签
phrases = list(set(phrases))

# 获取嵌入并删除那些静态嵌入为0的短语
valid_embeddings5 = []
valid_phrases5 = []

missing_phrases = []  # 记录静态嵌入为0的短语

processed_phrases = []

# 创建一个映射从原始短语到其antonym或处理后的短语
phrase_to_antonym_mapping = {}

for phrase in phrases:
    # 在处理短语嵌入时，使用fasttext_model
    
    embedding = get_roberta_embedding(phrase,model,tokenizer)
    if embedding is not None:
        valid_embeddings5.append(embedding)
        valid_phrases5.append(phrase)
    else:
        missing_phrases.append(phrase)
        
cluster = AgglomerativeClustering(n_clusters=None, distance_threshold=0).fit(valid_embeddings5)

linked = linkage(valid_embeddings5, method='ward')

plt.figure(figsize=(30, 25))
subset_phrases = [phrase if idx % 5 == 0 else '' for idx, phrase in enumerate(valid_phrases5)]
dendrogram(linked, orientation='left', labels=subset_phrases)

plt.show()
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
## SPanbert
import torch
import numpy as np
import pandas as pd
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
from nltk.corpus import wordnet

# Load model directly
from transformers import AutoModel,AutoTokenizer
model = AutoModel.from_pretrained("SpanBERT/spanbert-base-cased")
tokenizer = AutoTokenizer.from_pretrained("SpanBERT/spanbert-base-cased")


def get_spanbert_embedding(text, model, tokenizer):
    inputs = tokenizer("I feel " + text, return_tensors="pt")
    # 获取模型输出
    with torch.no_grad():
        outputs = model(**inputs)
    # 使用[CLS]标记的嵌入作为句子的嵌入
    sentence_embedding = outputs.last_hidden_state[:, 0, :]
    return sentence_embedding

# 读取sentiment_results.csv中Final Sentiment为Positive的词
df = pd.read_csv('processed_phrase_fine_tune_res.csv')
phrases = df['phrases'].tolist()

# 去除重复标签
phrases = list(set(phrases))

# 获取嵌入并删除那些静态嵌入为0的短语
valid_embeddings6 = []
valid_phrases6 = []

missing_phrases = []  # 记录静态嵌入为0的短语

processed_phrases = []

# 创建一个映射从原始短语到其antonym或处理后的短语
phrase_to_antonym_mapping = {}

for phrase in phrases:
    # 在处理短语嵌入时，使用fasttext_model
    
    embedding = get_roberta_embedding(phrase,model,tokenizer)
    if embedding is not None:
        valid_embeddings6.append(embedding)
        valid_phrases6.append(phrase)
    else:
        missing_phrases.append(phrase)
        
cluster = AgglomerativeClustering(n_clusters=None, distance_threshold=0).fit(valid_embeddings6)

linked = linkage(valid_embeddings6, method='ward')

plt.figure(figsize=(30, 25))
subset_phrases = [phrase if idx % 5 == 0 else '' for idx, phrase in enumerate(valid_phrases6)]
dendrogram(linked, orientation='left', labels=subset_phrases)

plt.show()
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at SpanBERT/spanbert-base-cased and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
### Cophenetic Correlation Coefficient (CCC) 越大越好
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import cophenet

# 使用pdist计算原始距离
original_distances = pdist(valid_embeddings5)

# 使用cophenet计算cophenetic distances
coph_dists, coph_corr = cophenet(linked, original_distances)

print("Cophenetic Correlation Coefficient:", coph_corr)
# Out:
# Cophenetic Correlation Coefficient: [ 3.76116169 17.90155258 11.50279897 ...  8.34057342 17.90155258
#  17.90155258]

# %%
## 肘部法则

distances = linked[:80, 2]
inverse_distances = -distances
plt.plot(inverse_distances)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Merge distance (negative)')
plt.show()

# %%
## Davies-Bouldin Index 越小越好
from sklearn.metrics import davies_bouldin_score

cluster_range = range(20, 80) # assuming you want to check for up to 15 clusters
db_scores = []

for n_clusters in cluster_range:
    clusterer = AgglomerativeClustering(n_clusters=n_clusters)
    cluster_labels = clusterer.fit_predict(valid_embeddings6)
    db_score = davies_bouldin_score(valid_embeddings6, cluster_labels)
    db_scores.append(db_score)

plt.plot(cluster_range, db_scores, 'bo-')
plt.title('Davies-Bouldin Index vs. Number of Clusters')
plt.xlabel('Number of clusters')
plt.ylabel('Davies-Bouldin Index')
plt.show()

# %%
## Gap score 越大越好
from scipy.cluster.hierarchy import fcluster
from scipy.spatial.distance import pdist, squareform

def hierarchical_gap_statistic(X, linked, max_clusters, B=10): #参数B 通常表示我们希望生成的随机数据集（或称为参照数据集）的数量，用于比较与实际数据的聚类效果
    # Step 1: Cluster the real data and compute the total distance
    real_tot_dists = []
    for k in range(1, max_clusters+1):
        labels = fcluster(linked, k, criterion='maxclust')
        # Calculate pairwise distance
        dist_matrix = squareform(pdist(X))
        mask = (labels[:, None] == labels)
        tot_dist = dist_matrix[mask].sum() / 2
        real_tot_dists.append(tot_dist)
        
    # Step 2: Cluster the random data and compute the total distance
    random_tot_dists = np.zeros((B, max_clusters))
    for i in range(B):
        random_data = np.random.rand(*X.shape)
        random_linked = linkage(random_data, method='ward')
        for k in range(1, max_clusters+1):
            labels = fcluster(random_linked, k, criterion='maxclust')
            dist_matrix = squareform(pdist(random_data))
            mask = (labels[:, None] == labels)
            random_tot_dists[i, k-1] = dist_matrix[mask].sum() / 2
            
    gaps = np.log(np.mean(random_tot_dists, axis=0)) - np.log(real_tot_dists)
    return gaps

X = np.array(valid_embeddings5)
gaps = hierarchical_gap_statistic(X, linked, max_clusters=80)

# Plot the Gap values
plt.plot(range(60, 81), gaps, 'o-')
plt.title("Gap Statistic for Hierarchical Clustering")
plt.xlabel("Number of clusters")
plt.ylabel("Gap Value")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[122], line 34
#      31 gaps = hierarchical_gap_statistic(X, linked, max_clusters=80)
#      33 # Plot the Gap values
# ---> 34 plt.plot(range(60, 81), gaps, 'o-')
#      35 plt.title("Gap Statistic for Hierarchical Clustering")
#      36 plt.xlabel("Number of clusters")
#
# File ~/spacy_nlp/.venv/lib/python3.11/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/spacy_nlp/.venv/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File ~/spacy_nlp/.venv/lib/python3.11/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/spacy_nlp/.venv/lib/python3.11/site-packages/matplotlib/axes/_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (21,) and (80,)

# %%
#embeddings = [get_phrase_embedding(phrase, glove_embeddings) for phrase in phrases]

print(len(valid_embeddings4))
from sklearn.metrics import silhouette_score
from sklearn.cluster import AgglomerativeClustering
import numpy as np

# 定义可能的簇数量范围
possible_n_clusters = range(20,40)  # 最小为2，最大为样本数量-1

sil_scores = []

# 对每一个可能的簇数量进行评估
for num_clusters in possible_n_clusters:
    clusterer = AgglomerativeClustering(n_clusters=num_clusters)
    preds = clusterer.fit_predict(valid_embeddings4)
    
    # 计算轮廓系数并保存
    score = silhouette_score(valid_embeddings4, preds)
    print(score)
    sil_scores.append(score)

# 找到最大的轮廓系数值对应的簇数量
best_num_clusters = possible_n_clusters[np.argmax(sil_scores)]
print(f"Best number of clusters: {best_num_clusters}")
# Out:
# 108
# 0.034571126
# 0.03720947
# 0.0412684
# 0.044505745
# 0.047839906
# 0.04996026
# 0.05359021
# 0.05749762
# 0.059560254
# 0.061732385
# 0.06343376
# 0.06586331
# 0.06712798
# 0.07007151
# 0.07111653
# 0.07174383
# 0.07357066
# 0.075017005
# 0.07615544
# 0.07756535
# Best number of clusters: 39

# %%
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# 列表用于保存每个簇数的评分
scores = []

# 设置一个簇数范围，例如从2到20
cluster_range = range(11,31)

# 对于每个簇数进行一次聚类，并计算紧密度或误差
for n_clusters in cluster_range:
    cluster = AgglomerativeClustering(n_clusters=n_clusters, distance_threshold=None).fit(valid_embeddings4)
    silhouette_avg = silhouette_score(valid_embeddings4, cluster.labels_)
    scores.append(silhouette_avg)

# 使用matplotlib绘制簇数对应的误差
plt.figure(figsize=(10,6))
plt.plot(cluster_range, scores, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %%
import pandas as pd
from sklearn.cluster import AgglomerativeClustering

# 进行聚类
cluster = AgglomerativeClustering(n_clusters=15, distance_threshold=None).fit(valid_embeddings4) ###31 48 60

# 创建一个字典，其中键是聚类ID，值是该聚类中的标签列表
clusters = {i: [] for i in range(cluster.n_clusters)}

for label, phrase in zip(cluster.labels_, valid_phrases4):
    clusters[label].append(phrase)


# 创建一个字典来保存聚类结果，之后再转为DataFrame
cluster_dict = {}

# 为每个聚类创建一个键值对
for cluster_id, cluster_phrases in clusters.items():
    cluster_dict[f"Cluster_{cluster_id}"] = cluster_phrases

# 对每个聚类中的词汇进行填充（为了DataFrame的对齐）
max_length = max(len(v) for v in cluster_dict.values())
for key, value in cluster_dict.items():
    value.extend([None] * (max_length - len(value)))

# 转为DataFrame
df_clusters = pd.DataFrame(cluster_dict)

# 保存到CSV文件中
df_clusters.to_csv("cn_negative_clusters.csv", index=False)

# %%
import networkx as nx

# 创建一个无向图
G = nx.Graph()

# 添加节点
G.add_nodes_from(["Alice", "Bob", "Charlie", "David", "Eve"])

# 添加边来表示朋友关系
G.add_edges_from([
    ("Alice", "Bob"),
    ("Alice", "Charlie"),
    ("Bob", "Charlie"),
    ("Alice", "David"),
    ("Charlie", "David"),
    ("David", "Eve")
])

# 计算整个图的平均聚类系数
avg_clustering = nx.average_clustering(G)
print(f"Average Clustering Coefficient: {avg_clustering}")

# 计算每个节点的聚类系数
clustering = nx.clustering(G)
for node, coeff in clustering.items():
    print(f"{node}: {coeff}")
# Out:
# Average Clustering Coefficient: 0.5333333333333333
# Alice: 0.6666666666666666
# Bob: 1.0
# Charlie: 0.6666666666666666
# David: 0.3333333333333333
# Eve: 0

# %%
## 聚类结果的可视化
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

from sklearn.cluster import AgglomerativeClustering
n_clusters=68

cluster = AgglomerativeClustering(n_clusters=n_clusters, distance_threshold=None).fit(valid_embeddings4) ###
labels = cluster.labels_
print(labels)

all_embeddings_np = np.vstack(valid_embeddings4) ###
print(all_embeddings_np)
tsne_model = TSNE(perplexity=40, n_components=3, init='pca', n_iter=2500, random_state=23)
low_dim_data = tsne_model.fit_transform(all_embeddings_np)
# Out:
# [58 39 18 60 24 40  8  7 44 56  0 20 12 27 11 16 36 11  5 10 23  2  0 56
#  59 15 53 11 15 63 18  0 29 30 16  3 48 16 24 53 67 30 27 34 48 54 29 20
#  15 46 23 48 63 17 35  6  1  8 22  9 10 37  1 37 12 30 30 62 15 28 29 29
#  19 30 30 18 15 51 20  1 54 44 33 24 25  5 32 21 37 14  3 61  7  1 21  0
#  12  2 26 29 35 65 15 48 26 15 63 25 15 13 55 66 64  0 30 60 31 53  1 12
#  14  0 51 10  8  6 36 27 58 60 61 26 11 15 23 58  1 33 51 30 29 48  6 37
#  51 58 16  6 14 29 11 23 30 18 21 34 27 34 35 63 64 23 15  3 53 38 14 53
#  20 67 28  2  9  8  4  7  8 15 43 30 50 48  4 64 18 16  6 11 61 22 15 28
#  61  1  5 49 27  0  1 29 29 39 48 51 30 43 58 60  8 61 52 48 37 26 21  1
#  16 55 12 12 62 41 32 48 40  7 14 11 66 66 58  7 64 33  4 11 60 15 15 47
#   1 44  2 47 32 23 15 18 29 23 58 13 55  2 44  0 59 14  0 15 64 17 63 53
#  51  1 17 41 52 12 48 18 30 40  2 29 15  7 47 35 65 51 15 10 58 19 28 64
#   0 53 18 63 49 31 14 39  6  3 37  0  7  1 18 24 29 26  6 65 11 27 13  1
#  35  0 55  0  6 65 12 11 19  1 13  0  1 17 67 45 21 40 17 11 43 24 11 58
#  62 67 60 27 26 22 55 43 61  9 46 14 22 48 11 20 32 47 67 37 10 49 51 25
#  48 64 62 32 61 37 23  8 12 55 53 55 48 43 28 27 32 46  7 15  1 20 29 16
#   2 35 46 64 26 66  9 37 67 48 15 21  0  0 35  8 39 13 41 29 43  6 21 58
#  27 37 43 36 51 59  8 16 30  0 35 21 11 31 12 49 53 34  3 36 14 31 54 36
#  24 56  9  5 37  5 25 62 57 60 67  4 43 65 17 53  0 25 32 24 11 17  3 31
#  15 50  1 60  7  6 39 37 16 34 67 21  7 27 26 28  9 34 11 15 25 53 40 10
#  46 30 37 35  6  5 48 28  1 39 55 13 39 32 62 47 44  7  8  5 14 57 17 24
#  23 15  4 32 63 31  0 67 16 21  8 26 33 40  0 54 15 17 58 21 16 45 66 67
#   9  0 19 58 19 55 10 34 58 16 57 41 30 38 56 62 47 63  4 11 46 37 57 16
#  63 26 34 30 28 29 41 36 32 64 27 45 58 63 23  8  6  1 13 36 64 55 29 31
#  26 67 15 27 37 66 29 13  0 20 61 35  9 16 51 26 16 11  6 11  5 55 58  8
#  34  0  4 23 63 39 21 35 24 53 53 46 17 40 37 65 40 31 37 35 29 22 18 28
#  12 12 50  6  0 20 31 26  7 53 51 27  7 18 10 13 20 50  5 47 29 48 13 25
#   5  1 37 30 30 19 56 33 27 18 38  1 26 29 41  8 54 62 58 37 42 50  5 67
#  28 37 40 41 11 22 11  2  1]
# [[ 0.68046474  0.10760731  0.3674053  ... -0.22970943  0.23546724
#   -0.00440329]
#  [ 0.52715695  0.19942918  0.1576118  ... -0.01789306  0.31940526
#   -0.00302497]
#  [ 0.6958414   0.19990692  0.37769428 ... -0.19806613  0.36256683
#   -0.12206098]
#  ...
#  [ 0.42529085  0.2917952   0.20871457 ... -0.21649924  0.1545727
#   -0.08042339]
#  [ 0.55403996 -0.12879235  0.21235155 ... -0.08036506  0.43873924
#   -0.1363683 ]
#  [ 0.4993965   0.12781368  0.01298354 ... -0.33464575  0.25429058
#   -0.38896626]]
# Python(24968) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.

# %%
import plotly.graph_objects as go

text = []
print(valid_phrases4) ###
for phrase, label in zip(valid_phrases4, labels): ###
    text.append('words: ' + phrase + ' label: ' + str(label))

fig = go.Figure(data=[
    go.Scatter3d(
        x=low_dim_data[:, 0],
        y=low_dim_data[:, 1],
        z=low_dim_data[:, 2],
        mode='markers',
        marker=dict(size=2, color=labels),
        text=text,  # 设置每个点的标签
        hoverinfo='text'  # 当悬停在点上时，只显示text内容
    )
])

fig.update_layout(title="3D t-SNE Visualization with Words", width=800, height=600)
fig.show()
# Out:
# ['calloused fingers', 'moving my finger', 'downstairs neighbor', 'less deep', 'chill out', 'doing well', 'talk deeply', 'stroll on the beach', 'pane of glass', "something's coming up", 'small bird', 'long sensation', 'computer screen', 'bounce back', 'Petting dog', 'sprinklers watering system', 'bad bit', "don't go", 'brush your feet', 'small alarm clock', 'shoot somebody', 'science museums', 'little dog', 'something wrong', 'phone vibrates', 'dramatic music', 'painted furniture', 'last one', 'ant-eater-type', 'tiny millipede', 'forces pushing', 'gentle buzz', 'rubbing a balloon', 'not nudging in a certain direction', 'squeaking noise', "feel someone's heartbeat", 'On even', 'rubber boots', 'not gently woken up', 'snow ice pieces', 'blunt kitchen knife', 'get rid of', 'sticking to their guns', 'background noise', 'different on each finger', 'dance music', 'stuck in the mud', 'long time', 'run it around', 'cleaning kitchen', 'comes and goes', 'eights in that with my finger', 'tiny little things', 'something important', "can't work out", 'Touching something delicate', "I don't get it", 'Deep thought', 'Sensual sensuality', 'come back full force', 'fancy alarm clock', 'old-school', 'not as pleasant', 'neutral way', 'remote controller', 'want to push against it', 'be careful', 'not as smooth as glass', 'perspex glass', 'light vibration', 'rolling animal', 'roll itself', "do what you're supposed to do", "wouldn't want to voluntarily touch it", 'get away', 'work moving around', 'coarse feeling', 'no pattern', 'slow down', 'not hard-working', 'music playing', 'carpet sensation', 'further apart', 'just chilled out', 'better foreboding', 'arms around your waist', 'vibration setting', 'infrared lights', 'Not very different', 'holding back', "someone's chest", 'not in any danger', 'outside of a car', 'not a constant kind of vibration', 'electric pulse', 'tiny motor', 'fingerprint button on an iPhone', 'marching band drummer', 'drawing shapes', 'running cloth', 'forgot what cartoon', 'feel-good', 'small outbursts', 'barely feel', 'kitchen appliances', 'menial tasks', 'tiny steps', 'anxious feeling', 'fuzzy onomatopoeia', 'working at a fast pace', 'tummy growling', 'being chased', 'nearly there', 'little bird', 'want to wear it down', 'more spacing', 'a bit of a stoner', 'manmade metallic structures', 'not aggressive pulse', 'annoying ringtones', 'trying to make slow down', 'little thing', 'nothing happening', 'iPhone alarm', 'no obstruction', 'obvious pulsing rhythm', 'get worse', 'blood taken', 'massage chair', 'less rhythmic', 'not specific action', "kid's iPad", 'TV thing', 'weird outbursts', 'personal printer from the early 2000s', 'tingling in fingers', 'not constantly buzzing', 'far apart', 'no difference', "shouldn't be there", 'running machine', 'difficult to distinguish', 'soft vibration', 'jigsaw puzzles', 'no signals', 'ice cream', 'touching something rubbery', 'light rumbling', 'pushing back', 'hopping alone', 'same motor', 'binary state', 'platform ready to go', 'Millipede marchig around', 'liquid sensation', 'heart beating', 'knife-edge', 'white noise', "doesn't change", 'tiny bits of them', 'imagining it', 'negative feelings', 'false idea', 'close to someone', 'bamboo woods', 'jumping up and down', 'pumping out', 'sticker glue', 'long snout', 'down the balloon', 'very light bumps', 'spaceship games', 'live progress', 'not pure glass', 'continuous buzz', 'window of a car', 'communication through glass', 'factory-wide alarm', "doesn't have much substance", 'not reminding anything', 'holds you back', 'not even detect', 'high beat frequency', 'struggling to feel it', 'floats around', 'metal pin', 'Deep voice', 'hanging out', 'not bring attention to itself', 'spatial separation', 'lower physical effort', 'normal window', 'an inconvenience', 'not smoothly gliding', 'run your hands over', 'on and off', 'laser tag', 'small stops', 'not in a bad way', 'peeled an orange', 'running over stuff', 'stop moving a finger', 'barely noticeab ...

# %%
## 将processed_sentiment转为小写
import pandas as pd

# 读取CSV文件
df = pd.read_csv("processed_with_antonyms3.csv") ###这个是合并了pos和neg的反义词，是手工合并的
#df = pd.read_csv("processed_phrase_fine_tune_res.csv") 

# 针对FastText
#df = pd.read_csv("processed_un_sentiment_results.csv")

# # 将filtered_words这一列转为小写
# df['filtered_words'] = df['filtered_words'].str.lower()

#将signal的顺序与sequence中信号顺序一一对应
sequences_df = pd.read_csv("sequences.csv", header=None)

# 2. 根据sentiment_df中的Signal值和Participants来找到sequences_df中的新Signal值
def get_new_signal(row):
    # 获取当前Signal值
    current_signal = row['Signal']
    # 获取当前Participants值
    participant = row['Participants']
    # 返回sequences_df中对应的新Signal值
    return sequences_df.iloc[participant-1, current_signal-1]

# 更新Signal列
df['Signal'] = df.apply(get_new_signal, axis=1)


# 保存到新的CSV文件中
df.to_csv("processed_uncase_sentiment_results3.csv", index=False)
#df.to_csv("processed_phrase_32_signal.csv", index=False)

# %%
import pandas as pd

# 读取数据
sentiment_df = pd.read_csv('processed_uncase_sentiment_results.csv')
positive_clusters_df = pd.read_csv('g3_pos_clusters.csv')
negative_clusters_df = pd.read_csv('g3_neg_clusters.csv')

# 定义一个函数来获取cluster的值
def get_cluster(row):
    if row['Final Sentiment'] == 'Positive':
        clusters_df = positive_clusters_df
    elif row['Final Sentiment'] == 'Negative':
        clusters_df = negative_clusters_df
    else:
        return None

    for column in clusters_df.columns:
        if row['filtered_words'] in clusters_df[column].tolist():
            return column.split('_')[-1]  # 获取_后的数字部分

    return None

# 应用函数并设置Cluster的值
sentiment_df['Cluster'] = sentiment_df.apply(get_cluster, axis=1)

# 保存修改后的数据
sentiment_df.to_csv('g3_processed_uncase_sentiment_results.csv', index=False)

# %%
## 计算覆盖率
import pandas as pd

# 读取两个CSV文件
sentiments = pd.read_csv("processed_uncase_sentiment_results3.csv")
clusters = pd.read_csv("cn_negative_clusters.csv")

# 计算每个Signal中的Cluster的单词涵盖率
results = []

unique_signals = sentiments['Signal'].unique()
for signal in unique_signals:
    filtered_words_for_signal = sentiments[sentiments['Signal'] == signal]['filtered_words'].tolist() ###
    coverage = {'Signal': signal}
    
    for cluster_col in clusters.columns:
        cluster_words = clusters[cluster_col].dropna().tolist()
        covered_words = set(filtered_words_for_signal) & set(cluster_words)
        coverage_rate = len(covered_words) / len(cluster_words) if cluster_words else 0
        coverage[cluster_col] = coverage_rate
    
    results.append(coverage)

coverage_df = pd.DataFrame(results)

# 保存结果为新的CSV文件
coverage_df.to_csv("coverage_cn_neg_results.csv", index=False)

# %%
import pandas as pd

# 读取CSV文件
df = pd.read_csv("/Users/zhaozirui/Desktop/ASU-visiting student/features.csv")

# 为除了'id'列之外的所有列进行归一化
for column in df.columns:
    if column != 'id':
        df[column] = (df[column] - df[column].min()) / (df[column].max() - df[column].min())

# 保存到新的CSV文件中
df.to_csv("normalized_features.csv", index=False)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 读取CSV文件
features = pd.read_csv("normalized_features.csv")
coverage = pd.read_csv("coverage_cn_neg_results.csv")

# 确保两个文件按Signal列对齐
merged_data = features.merge(coverage, on='Signal')

# 计算Pearson相关系数
correlation_matrix = merged_data.corr()
clusters = [col for col in coverage.columns if col.startswith("Cluster")]
correlation_results = correlation_matrix[clusters].loc[features.columns[1:]]  # 从索引1开始，因为索引0是Signal列

# 使用热图显示相关系数
plt.figure(figsize=(12, 8)) ###
sns.heatmap(correlation_results, annot=True, cmap='coolwarm', center=0)
plt.title("Pearson Correlation between Features and Clusters")
plt.tight_layout()
plt.savefig("correlation_heatmap.png")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 读取CSV文件
features = pd.read_csv("normalized_features.csv")
coverage = pd.read_csv("coverage_cn_pos_results.csv")

# 确保两个文件按Signal列对齐
merged_data = features.merge(coverage, on='Signal')

# 计算Pearson相关系数
correlation_matrix = merged_data.corr()
clusters = [col for col in coverage.columns if col.startswith("Cluster")]
correlation_results = correlation_matrix[clusters].loc[features.columns[1:]]  # 从索引1开始，因为索引0是Signal列

# 创建一个mask，其中大于等于0.1或小于等于-0.1的值为False，其他值为True
mask = (correlation_results >= 0.1) | (correlation_results <= -0.1)
mask = ~mask  # 对mask取反，因为我们想屏蔽的是True值

# 使用热图显示相关系数，并使用mask参数屏蔽不需要的值
#plt.figure(figsize=(12, 8))###
plt.figure(figsize=(12, 8))

sns.heatmap(correlation_results, annot=True, cmap='coolwarm', center=0, mask=mask)
plt.title("Pearson Correlation between Features and Clusters")
plt.tight_layout()
plt.savefig("correlation_heatmap.png")
plt.show()

# 将correlation_results保存为CSV文件
correlation_results.to_csv("pearson_correlation_results.csv")

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import AgglomerativeClustering

# 假设 valid_embeddings3 是已经准备好的embedding列表
# 进行聚类
cluster = AgglomerativeClustering(n_clusters=15, distance_threshold=None).fit(valid_embeddings4)###

# 创建一个字典来保存每个聚类的embedding总和和计数
embeddings_sum = {i: np.zeros_like(valid_embeddings4[0]) for i in range(cluster.n_clusters)}###
embeddings_count = {i: 0 for i in range(cluster.n_clusters)}

# 计算每个聚类的embedding总和和计数
for label, embedding in zip(cluster.labels_, valid_embeddings4):###
    embeddings_sum[label] += embedding
    embeddings_count[label] += 1

# 计算每个聚类的embedding平均值
average_embeddings = {i: embeddings_sum[i] / embeddings_count[i] for i in range(cluster.n_clusters)}

# 将平均embeddings转换为一个DataFrame
df_average_embeddings = pd.DataFrame.from_dict(average_embeddings, orient='index')


# 计算余弦相似度矩阵
cosine_sim_matrix = cosine_similarity(df_average_embeddings)

# 将余弦相似度矩阵转换为DataFrame
df_cosine_sim = pd.DataFrame(cosine_sim_matrix)

# 保存余弦相似度矩阵到CSV
df_cosine_sim.to_csv("cn_neg_cosine_similarity.csv", index=False)
